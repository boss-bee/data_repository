# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
pes_1 = np.load("hf_qedcasci_6_16_6_311ppGss_om_0.63_lz_0.01_pes_16_el_states_5_ph_states_only_singlets_10_points_1.npy_pes.npy")
pes_2 = np.load("hf_qedcasci_6_16_6_311ppGss_om_0.63_lz_0.01_pes_16_el_states_5_ph_states_only_singlets_10_points_2.npy_pes.npy")
pes_3 = np.load("hf_qedcasci_6_16_6_311ppGss_om_0.63_lz_0.01_pes_16_el_states_5_ph_states_only_singlets_10_points_3.npy_pes.npy")
pes_4 = np.load("hf_qedcasci_6_16_6_311ppGss_om_0.63_lz_0.01_pes_16_el_states_5_ph_states_only_singlets_10_points_4.npy_pes.npy")

np.shape(pes_4)
dim=3*11+8
pes = np.zeros((17,dim))

pes[:,:11] = np.copy(pes_1)
pes[:,11:22] = np.copy(pes_2)
pes[:,22:33] = np.copy(pes_3)
pes[:,33:41] = np.copy(pes_4)

# %%
#plt.plot(pes[0,:], pes[1,:], 'black')
plt.plot(pes[0,:], pes[6,:], 'ro')
plt.plot(pes[0,:], pes[7,:], 'yo')
#plt.plot(pes[0,:], pes[8,:], 'bo')
#plt.plot(pes[0,:], pes[9,:], 'go')
#plt.plot(pes[0,:], pes[11,:], 'r^')

plt.ylim(-100.2, -98.5)
# Out:
# (-100.2, -98.5)
