# %%
import psi4
import nglview

# %%
mol = psi4.geometry('pubchem:1-Bromo-2-nitrobenzene')
view = nglview.show_psi4(mol)
view
# Out:
# 	Searching PubChem database for 1-Bromo-2-nitrobenzene (single best match returned)
# 	Found 1 result(s)
# NGLWidget()

# %%
options_dict = {
    "basis": "6-311G*",
    "scf_type": "df",
    "e_convergence": 1e-10,
    "d_convergence": 1e-10,
}

mol = psi4.geometry('pubchem:1-Bromo-2-nitrobenzene')
psi4.set_options(options_dict)
psi4.optimize('MP2', return_wfn=True)
# Out:
# 	Searching PubChem database for 1-Bromo-2-nitrobenzene (single best match returned)
# 	Found 1 result(s)
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYY31VALT
# *** at Fri Mar 22 09:29:53 2024
#
#    => Loading Basis Set <=
#
#     Name: 6-311G*
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1     entry BR         line   819 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-311gs.gbs
#     atoms 2-3   entry O          line   152 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-311gs.gbs
#     atoms 4     entry N          line   133 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-311gs.gbs
# ...

# %%
mol_str = """
    BR           0.323802875985    -1.819561853051     0.000758140714
    O            1.816822531663     2.538127191740     0.003303867287
    O            2.211230565783     0.399329776938    -0.004688388112
    N            1.455218824319     1.364246605406    -0.000560365476
    C           -0.008454952752     1.113339178330    -0.000353116484
    C           -0.590256222928    -0.166907228547    -0.000226437305
    C           -0.816019362182     2.256424064908    -0.000536013427
    C           -1.991538202294    -0.256748422210    -0.000189573980
    C           -2.202046728009     2.145398961346    -0.000576964886
    C           -2.793654126009     0.880553864042    -0.000452991290
    H           -0.331483470666     3.224756180842    -0.000612891277
    H           -2.444072155736    -1.242995890487     0.000038418707
    H           -2.812167684708     3.043243642976    -0.000764793648
    H           -3.874486411919     0.773673231247    -0.000464523824
1 1
"""

# %%
mol2 = psi4.geometry('pubchem:1-Bromo-4-nitrobenzene')
view2 = nglview.show_psi4(mol2)
view2
# Out:
# 	Searching PubChem database for 1-Bromo-4-nitrobenzene (single best match returned)
# 	Found 1 result(s)
# NGLWidget()

# %%
# 1-Bromo-3-nitrobenzene
mol3 = psi4.geometry('pubchem:1-Bromo-3-nitrobenzene')
view3 = nglview.show_psi4(mol3)
view3
# Out:
# 	Searching PubChem database for 1-Bromo-3-nitrobenzene (single best match returned)
# 	Found 1 result(s)
# NGLWidget()
