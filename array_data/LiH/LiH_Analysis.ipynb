# %% [markdown]
# H2_0.json		H2_0_04.json		dipoles_H20_02.npy
# H2_0_001.json		H2_0_05.json		dipoles_H20_03.npy
# H2_0_005.json		dipoles_H20.npy		dipoles_H20_04.npy
# H2_0_01.json		dipoles_H20_001.npy	dipoles_H20_05.npy
# H2_0_02.json		dipoles_H20_005.npy
# H2_0_03.json		dipoles_H20_01.npy

# %%
import json
import numpy as np
from matplotlib import pyplot as plt

# %%
LiH_cavity_free = json.load(open("LiH_0.json"))

LiH_cavity = json.load(open("LiH_0_05.json"))

LiH_cavity_free['basis_set']
# Out:
# '6-311G'

# %%
r = np.array(LiH_cavity_free['r_data'])
en = np.array(LiH_cavity_free['energy_arrays0'])
en_cav = np.array(LiH_cavity['energy_arrays0_05'])
om = float(LiH_cavity['omega_value'])
print(om)
print(om * 27.2114)
# Out:
# 0.12086
# 3.288769804

# %%
#plt.plot(r, en[0,:], label="|g>")
#plt.plot(r, en[0,:]+float(om), 'bo', label="|g>+ w")
#plt.plot(r, en[1,:], label="|e1>")
plt.plot(r, en[2,:], label="|e2>")
#plt.plot(r, en[3,:], label="|e3>")
#plt.plot(r, en[4,:], label="|e4>")

#plt.plot(r, en_cav[0,:], label="Coupled Eg")
#plt.plot(r, en_cav[1,:], label="Coupled E1")
#plt.plot(r, en_cav[2,:], label="Coupled LP")
#plt.plot(r, en_cav[3,:], label="Coupled UP")
#plt.plot(r, en_cav[4,:])
plt.xlim(2.2, 2.75)
plt.ylim(-7.914, -7.91)
plt.grid()
plt.legend()
plt.show()

# %%
+
