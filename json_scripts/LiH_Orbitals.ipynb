# %%
from __future__ import print_function

"""
A script to run cqed_rhf method on the formaldehyde molecule in a cc-pVDZ basis set
and plot the HOMO and LUMO+1 orbitals under strong and no-coupling to a photon
polarized along the $y-z$ axis, as shown in Figure 1 of McTague and Foley.
"""

__authors__   = ["Jon McTague", "Jonathan Foley"]
__credits__   = ["Jon McTague", "Jonathan Foley"]

__copyright_amp__ = "(c) 2014-2018, The Psi4NumPy Developers"
__license__   = "BSD-3-Clause"
__date__      = "2021-01-15"

# ==> Import Psi4, NumPy, & SciPy <==
import psi4
import numpy as np
from helper_cqed_rhf import *
from matplotlib import pyplot as plt
import fortecubeview

# Set Psi4 & NumPy Memory Options
psi4.set_memory('2 GB')
#psi4.core.set_output_file('output.dat', False)

numpy_memory = 2
# Out:
#   Memory set to   1.863 GiB by Python driver.

# %%
# options dict
options_dict = {'basis': '6-311g',
               'save_jk': True, 
               'scf_type': 'pk',
               'e_convergence' : 1e-10,
               'd_convergence' : 1e-10}

psi4.set_options(options_dict)

molstr = """
Li
H 1 1.9
symmetry c1
"""
mol = psi4.geometry(molstr)
energy, wfn = psi4.energy("scf/6-311g", molecule=mol, return_wfn=True)
psi4.set_options({
    'CUBEPROP_TASKS': ['ORBITALS'], 
    'CUBEPROP_ORBITALS': [1,11,12,13,14,15,16],
})
cube = psi4.cubeprop(wfn)
fortecubeview.plot(width=500,height=800,colorscheme='emory', sumlevel=.55)
# Out:
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
#
# *** tstart() called on Jessicas-iMac.local
# *** at Wed Dec 13 15:02:15 2023
#
#    => Loading Basis Set <=
#
#     Name: 6-311G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    41 file /opt/anaconda3/envs/psi4env/share/psi4/basis/6-311g.gbs
#     atoms 2 entry H          line    21 file /opt/anaconda3/envs/psi4env/share/psi4/basis/6-311g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.238647619235     7.016003436600
#          H            0.000000000000     0.000000000000     1.661352380765     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      5.29903  C =      5.29903 [cm^-1]
#   Rotational constants: A = ************  B = 158860.78312  C = 158860.78312 [MHz]
#   Nuclear repulsion =    0.835542964215790
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-311G
#     Blend: 6-311G
#     Number of shells: 10
#     Number of basis functions: 16
#     Number of Cartesian functions: 16
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              10
#       Number of primitives:             21
#       Number of atomic orbitals:        16
#       Number of basis functions:        16
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 18632 doubles for integral storage.
#   We computed 1540 shell quartets total.
#   Whereas there are 1540 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:             1430
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 5.2853980784E-02.
#   Reciprocal condition number of the overlap matrix is 1.4945096678E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         16      16
#    -------------------------
#     Total      16      16
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.69654328835904   -7.69654e+00   0.00000e+00
#    @RHF iter   1:    -7.96071615506782   -2.64173e-01   6.32443e-03 DIIS
#    @RHF iter   2:    -7.97624222583347   -1.55261e-02   9.43860e-04 DIIS
#    @RHF iter   3:    -7.97687132263820   -6.29097e-04   2.67615e-04 DIIS
#    @RHF iter   4:    -7.97694476265426   -7.34400e-05   7.35634e-05 DIIS
#    @RHF iter   5:    -7.97695256408942   -7.80144e-06   1.08805e-05 DIIS
#    @RHF iter   6:    -7.97695270270850   -1.38619e-07   9.56616e-07 DIIS
#    @RHF iter   7:    -7.97695270398350   -1.27500e-09   5.33349e-08 DIIS
#    @RHF iter   8:    -7.97695270398592   -2.41585e-12   7.88244e-09 DIIS
#    @RHF iter   9:    -7.97695270398597   -5.24025e-14   9.38759e-10 DIIS
#    @RHF iter  10:    -7.97695270398598   -9.76996e-15   1.64182e-10 DIIS
#    @RHF iter  11:    -7.97695270398596    1.59872e-14   6.42591e-12 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.477157     2A     -0.285459
#
#     Virtual:
#
#        3A     -0.007118     4A      0.038999     5A      0.038999
#        6A      0.091624     7A      0.109921     8A      0.144867
#        9A      0.144867    10A      0.213984    11A      0.539933
#       12A      0.568626    13A      0.568626    14A      0.622632
#       15A      2.805550    16A      3.946136
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#
#   @RHF Final Energy:    -7.97695270398596
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.8355429642157898
#     One-Electron Energy =                 -12.0997596959050036
#     Two-Electron Energy =                   3.2872640277032521
#     Total Energy =                         -7.9769527039859618
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:     1.7866
#
#   Electronic Dipole Moment: [e a0]
#      X:    -0.0000      Y:     0.0000      Z:    -4.4554
#
#   Dipole Moment: [e a0]
#      X:    -0.0000      Y:     0.0000      Z:    -2.6688     Total:     2.6688
#
#   Dipole Moment: [D]
#      X:    -0.0000      Y:     0.0000      Z:    -6.7834     Total:     6.7834
#
#
# *** tstop() called on Jessicas-iMac.local at Wed Dec 13 15:02:15 2023
# Module time:
# 	user time   =       0.11 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      10.26 seconds =       0.17 minutes
# 	system time =       0.45 seconds =       0.01 minutes
# 	total time  =       1406 seconds =      23.43 minutes
# CubeViewer: listing cube files from the directory .  ==> One Electron Grid Properties (v2.0) <==
#
#   ==> CubicScalarGrid <==
#
#
#     Filepath     = .
#     Total Points =            99179
#     XYZ Blocking =               10
#     X Points     =               41
#     Y Points     =               41
#     Z Points     =               59
#     X Spacing    =        2.000E-01
#     Y Spacing    =        2.000E-01
#     Z Spacing    =        2.000E-01
#     X Minimum    =       -4.000E+00
#     Y Minimum    =       -4.000E+00
#     Z Minimum    =       -4.456E+00
#     X Maximum    =        4.000E+00
#     Y Maximum    =        4.000E+00
#     Z Maximum    =        7.144E+00
#
#   Basis Set: 6-311G
#     Blend: 6-311G
#     Number of shells: 10
#     Number of basis functions: 16
#     Number of Cartesian functions: 16
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
# Reading 7 cube files
# VBox(children=(HTML(value=''), Renderer(camera=OrthographicCamera(bottom=-8.0, children=(DirectionalLight(colo…
# HTML(value='\n        <style>\n           .jupyter-widgets-output-area .output_scroll {\n                heigh…
# interactive(children=(Select(description='Cube files:', options=('MO    1a (1-A)', 'MO   11a (11-A)', 'MO   12…

# %%
help(fortecubeview.plot)

# %%
lam = np.array([0, 0, 0.05])
# run our CQED-RHF calculation and store the results in a dictionary called 'yz_dict'
dict = cqed_rhf(lam, molstr, options_dict)

# get the CQED-RHF orbitals from yz_dict
C = dict['CQED-RHF C']

# get the psi4 wavefunction as a dictionary
rhf_wfn_dict = psi4.core.Wavefunction.to_file(wfn)

# swap out orbitals in the dictionary with our orbitals from CQED-RHF
rhf_wfn_dict['matrix']['Ca'] = C
rhf_wfn_dict['matrix']['Cb'] = C

# Now create a new wavefunction object that has the CQED-RHF orbitals 'cqedrhf_wfn'
cqedrhf_wfn = psi4.core.Wavefunction.from_file(rhf_wfn_dict)
# Out:
# Scratch directory: /tmp/
#
# *** tstart() called on Jessicas-iMac.local
# *** at Wed Dec 13 15:07:43 2023
#
#    => Loading Basis Set <=
#
#     Name: 6-311G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    41 file /opt/anaconda3/envs/psi4env/share/psi4/basis/6-311g.gbs
#     atoms 2 entry H          line    21 file /opt/anaconda3/envs/psi4env/share/psi4/basis/6-311g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.238647619235     7.016003436600
#          H            0.000000000000     0.000000000000     1.661352380765     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      5.29903  C =      5.29903 [cm^-1]
#   Rotational constants: A = ************  B = 158860.78312  C = 158860.78312 [MHz]
#   Nuclear repulsion =    0.835542964215790
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-311G
#     Blend: 6-311G
#     Number of shells: 10
#     Number of basis functions: 16
#     Number of Cartesian functions: 16
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              10
#       Number of primitives:             21
#       Number of atomic orbitals:        16
#       Number of basis functions:        16
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 18632 doubles for integral storage.
#   We computed 1540 shell quartets total.
#   Whereas there are 1540 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:             1430
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 5.2853980784E-02.
#   Reciprocal condition number of the overlap matrix is 1.4945096678E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         16      16
#    -------------------------
#     Total      16      16
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.69654328835904   -7.69654e+00   0.00000e+00
#    @RHF iter   1:    -7.96071615506782   -2.64173e-01   6.32443e-03 DIIS
#    @RHF iter   2:    -7.97624222583347   -1.55261e-02   9.43860e-04 DIIS
#    @RHF iter   3:    -7.97687132263820   -6.29097e-04   2.67615e-04 DIIS
#    @RHF iter   4:    -7.97694476265426   -7.34400e-05   7.35634e-05 DIIS
#    @RHF iter   5:    -7.97695256408942   -7.80144e-06   1.08805e-05 DIIS
#    @RHF iter   6:    -7.97695270270850   -1.38619e-07   9.56616e-07 DIIS
#    @RHF iter   7:    -7.97695270398350   -1.27500e-09   5.33349e-08 DIIS
#    @RHF iter   8:    -7.97695270398592   -2.41585e-12   7.88244e-09 DIIS
#    @RHF iter   9:    -7.97695270398597   -5.24025e-14   9.38759e-10 DIIS
#    @RHF iter  10:    -7.97695270398598   -9.76996e-15   1.64182e-10 DIIS
#    @RHF iter  11:    -7.97695270398596    1.59872e-14   6.42591e-12 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.477157     2A     -0.285459
#
#     Virtual:
#
#        3A     -0.007118     4A      0.038999     5A      0.038999
#        6A      0.091624     7A      0.109921     8A      0.144867
#        9A      0.144867    10A      0.213984    11A      0.539933
#       12A      0.568626    13A      0.568626    14A      0.622632
#       15A      2.805550    16A      3.946136
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#
#   @RHF Final Energy:    -7.97695270398596
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.8355429642157898
#     One-Electron Energy =                 -12.0997596959050036
#     Two-Electron Energy =                   3.2872640277032521
#     Total Energy =                         -7.9769527039859618
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:     1.7866
#
#   Electronic Dipole Moment: [e a0]
#      X:    -0.0000      Y:     0.0000      Z:    -4.4554
#
#   Dipole Moment: [e a0]
#      X:    -0.0000      Y:     0.0000      Z:    -2.6688     Total:     2.6688
#
#   Dipole Moment: [D]
#      X:    -0.0000      Y:     0.0000      Z:    -6.7834     Total:     6.7834
#
#
# *** tstop() called on Jessicas-iMac.local at Wed Dec 13 15:07:43 2023
# Module time:
#
# Start SCF iterations:
# 	user time   =       0.10 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      13.81 seconds =       0.23 minutes
# 	system time =       0.58 seconds =       0.01 minutes
# 	total time  =       1734 seconds =      28.90 minutes
#
# Canonical RHF One-electron energy = -12.0997596960113221
# CQED-RHF One-electron energy      = -12.0756767546144825
# Nuclear repulsion energy          = 0.8355429642157898
# 1/2 <d_e>^2                       = 0.0248127712810491
# 1/2 d_N^2                         = 0.0039897684589338
# SCF Iteration   1: Energy = -7.9714048955362760   dE = -7.97140E+00   dRMS = 3.32658E-04
# SCF Iteration   2: Energy = -7.9714993367860654   dE = -9.44412E-05   dRMS = 1.12567E-04
# SCF Iteration   3: Energy = -7.9715139832834527   dE = -1.46465E-05   dRMS = 2.80248E-05
# SCF Iteration   4: Energy = -7.9715147287618056   dE = -7.45478E-07   dRMS = 3.91648E-06
# SCF Iteration   5: Energy = -7.9715147381470253   dE = -9.38522E-09   dRMS = 7.52174E-07
# SCF Iteration   6: Energy = -7.9715147386459471   dE = -4.98922E-10   dRMS = 5.19533E-08
# SCF Iteration   7: Energy = -7.9715147386470111   dE = -1.06404E-12   dRMS = 3.75307E-09
# SCF Iteration   8: Energy = -7.9715147386470075   dE =  3.55271E-15   dRMS = 7.37167E-10
# SCF Iteration   9: Energy = -7.9715147386470164   dE = -8.88178E-15   dRMS = 6.59434E-11
# Total time for SCF iterations: 0.008 seconds
#
# QED-RHF   energy: -7.97151474 hartree
# Psi4  SCF energy: -7.97695270 hartree
#    => Loading Basis Set <=
#
#     Name: 6-311G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    41 file /opt/anaconda3/envs/psi4env/share/psi4/basis/6-311g.gbs
#     atoms 2 entry H          line    21 file /opt/anaconda3/envs/psi4env/share/psi4/basis/6-311g.gbs

# %%
psi4.set_options({
    'CUBEPROP_TASKS': ['ORBITALS'], 
    'CUBEPROP_ORBITALS': [1,11,12,13,14,15,16],
})
cube = psi4.cubeprop(cqedrhf_wfn)
fortecubeview.plot(width=500,height=800,colorscheme='emory', sumlevel=.55)
# Out:
# CubeViewer: listing cube files from the directory .  ==> One Electron Grid Properties (v2.0) <==
#
#   ==> CubicScalarGrid <==
#
#     Filepath     = .
#     Total Points =            92455
#     XYZ Blocking =               10
#     X Points     =               41
#     Y Points     =               41
#     Z Points     =               55
#     X Spacing    =        2.000E-01
#     Y Spacing    =        2.000E-01
#     Z Spacing    =        2.000E-01
#     X Minimum    =       -4.000E+00
#     Y Minimum    =       -4.000E+00
#
#     Z Minimum    =       -4.409E+00
#     X Maximum    =        4.000E+00
#     Y Maximum    =        4.000E+00
#     Z Maximum    =        6.391E+00
#
#   Basis Set: 6-311G
#     Blend: 6-311G
#     Number of shells: 10
#     Number of basis functions: 16
#     Number of Cartesian functions: 16
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
# Reading 7 cube files
# VBox(children=(HTML(value=''), Renderer(camera=OrthographicCamera(bottom=-8.0, children=(DirectionalLight(colo…
# HTML(value='\n        <style>\n           .jupyter-widgets-output-area .output_scroll {\n                heigh…
# interactive(children=(Select(description='Cube files:', options=('MO    1a (1-A)', 'MO   11a (11-A)', 'MO   12…
