# %%
import json
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib import rcParams

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

# %%
# json file name
# uncc mac
cs_dir = "/Users/jfoley19/Code/data_repository/Mapol/BH3/qed_cas/6-31g/coherent_state_basis/"
pn_dir = "/Users/jfoley19/Code/data_repository/Mapol/BH3/qed_cas/6-31g/photon_number_basis/"
fci_dir = "/Users/jfoley19/Code/data_repository/Mapol/BH3/qed_fci/6-31g/coherent_state_basis/"

# imac
cs_dir = "/Users/jayfoley/Code/data_repository/Mapol/BH3/qed_cas/6-31g/coherent_state_basis/"
pn_dir = "/Users/jayfoley/Code/data_repository/Mapol/BH3/qed_cas/6-31g/photon_number_basis/"
fci_dir = "/Users/jayfoley/Code/data_repository/Mapol/BH3/qed_fci/6-31g/coherent_state_basis/"

fci_file = fci_dir + "bh3_qed-fci_6-31g_coherent_state_basis_1_8_13_omega_0.4805740782319994.json"
cas_6_14_file = cs_dir + "bh3_qed-cas_6-31g_coherent_state_basis_1_6_14_omega_0.4812826106029995.json"
cas_6_11_file = cs_dir + "bh3_qed-cas_6-31g_coherent_state_basis_1_6_11_omega_0.48725549307999927.json"
cas_6_7_file = cs_dir + "bh3_qed-cas_6-31g_coherent_state_basis_1_6_7_omega_0.5017350816120008.json"

pn_6_14_file = pn_dir + "bh3_qed-cas_6-31g_photon_number_basis_1_6_14_omega_0.4812826106029995.json"
pn_6_11_file = pn_dir + "bh3_qed-cas_6-31g_photon_number_basis_1_6_11_omega_0.48725549307999927.json"
pn_6_7_file = pn_dir + "bh3_qed-cas_6-31g_photon_number_basis_1_6_7_omega_0.5017350816120008.json"

fci_data = json.load(open(fci_file))
cas_6_14_data = json.load(open(cas_6_14_file))
cas_6_11_data = json.load(open(cas_6_11_file))
cas_6_7_data = json.load(open(cas_6_7_file))

pn_6_14_data = json.load(open(pn_6_14_file))
pn_6_11_data = json.load(open(pn_6_11_file))
pn_6_7_data = json.load(open(pn_6_7_file))

# %%
fci_energy = np.array(fci_data["return_result"])
cas_6_14_energy = np.array(cas_6_14_data["return_result"])
cas_6_11_energy = np.array(cas_6_11_data["return_result"])
cas_6_7_energy = np.array(cas_6_7_data["return_result"])

pn_6_14_energy = np.array(pn_6_14_data["return_result"])
pn_6_11_energy = np.array(pn_6_11_data["return_result"])
pn_6_7_energy = np.array(pn_6_7_data["return_result"])


#assert np.allclose(pn_6_14_energy, cas_6_14_energy, 1e-9)
#assert np.allclose(pn_6_11_energy, cas_6_11_energy, 1e-7)
#assert np.allclose(pn_6_7_energy, cas_6_7_energy, 1e-7)

omega_fci = fci_data["model"]["omega"]
omega_6_14 = cas_6_14_data["model"]["omega"]
omega_6_11 = cas_6_11_data["model"]["omega"]
omega_6_7 = cas_6_7_data["model"]["omega"]


pn_omega_6_14 = pn_6_14_data["model"]["omega"]
pn_omega_6_11 = pn_6_11_data["model"]["omega"]
pn_omega_6_7 = pn_6_7_data["model"]["omega"]

print(omega_6_14-pn_omega_6_14)
print(omega_6_11-pn_omega_6_11)
print(omega_6_7-pn_omega_6_7)
l_data = np.array(cas_6_14_data["model"]["lambda"])
# Out:
# 0.0
# 0.0
# 0.0

# %%
plt.plot(l_data[:,1], cas_6_14_energy[:,0]-fci_energy[:,0])
plt.plot(l_data[:,1], cas_6_11_energy[:,0]-fci_energy[:,0])
plt.plot(l_data[:,1], cas_6_7_energy[:,0]-fci_energy[:,0])
plt.yscale("log")
plt.xlabel("Coupling Strength (atomic units)")
plt.ylabel("Error (Hartrees)")
plt.ylim(5e-4, 1e-1)
plt.legend()
plt.grid()
plt.xlim(0, 0.05)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Sorting polariton states for the Coherent-State QED-CAS(6,14) method

# %%
lp_cas_6_14 = np.copy(cas_6_14_energy[:,10])
lp_cas_6_14[9:] = np.copy(cas_6_14_energy[9:,9])
up_cas_6_14 = np.copy(cas_6_14_energy[:,11])
up_cas_6_14[3:] = np.copy(cas_6_14_energy[3:,14])
up_cas_6_14[4:] = np.copy(cas_6_14_energy[4:,16])
up_cas_6_14[7:] = np.copy(cas_6_14_energy[7:,17])

# %%
plt.plot(l_data[:,1], cas_6_14_energy[:,0]+omega_6_14)
plt.plot(l_data[:,1], lp_cas_6_14, 'r--')
plt.plot(l_data[:,1], up_cas_6_14, 'r--')
plt.plot(l_data[:,1], cas_6_14_energy[:,9], "*")
plt.plot(l_data[:,1], cas_6_14_energy[:,10], "*")
plt.show()

# %% [markdown]
# # Sorting polariton states for the Photon Number QED-CAS(6,14) method

# %%
lp_pn_6_14 = np.copy(pn_6_14_energy[:,10])
lp_pn_6_14[9:] = np.copy(pn_6_14_energy[9:,9])
up_pn_6_14 = np.copy(pn_6_14_energy[:,11])
up_pn_6_14[3:] = np.copy(pn_6_14_energy[3:,14])
up_pn_6_14[4:] = np.copy(pn_6_14_energy[4:,16])
up_pn_6_14[7:] = np.copy(pn_6_14_energy[7:,17])

# %%
plt.plot(l_data[:,1], pn_6_14_energy[:,0]+omega_6_14)
plt.plot(l_data[:,1], lp_pn_6_14, 'r--')
plt.plot(l_data[:,1], up_pn_6_14, 'r--')
plt.plot(l_data[:,1], pn_6_14_energy[:,9], "*")
plt.plot(l_data[:,1], pn_6_14_energy[:,10], "*")
plt.show()

# %% [markdown]
# # Sorting polariton states for the Coherent-State QED-CAS(6,11) method

# %%
lp_cas_6_11 = np.copy(cas_6_11_energy[:,10])
#lp_cas_6_11[9:] = np.copy(cas_6_11_energy[9:,9])
up_cas_6_11 = np.copy(cas_6_11_energy[:,11])
up_cas_6_11[3:] = np.copy(cas_6_11_energy[3:,13])
#up_cas_6_11[4:] = np.copy(cas_6_11_energy[4:,16])
up_cas_6_11[5:] = np.copy(cas_6_11_energy[5:,17])

plt.plot(l_data[:,1], cas_6_11_energy[:,0]+omega_6_11)
plt.plot(l_data[:,1], lp_cas_6_11, 'r--')
plt.plot(l_data[:,1], up_cas_6_11, 'r--')
plt.plot(l_data[:,1], cas_6_11_energy[:,11], "*")
plt.plot(l_data[:,1], cas_6_11_energy[:,12], "*")
plt.plot(l_data[:,1], cas_6_11_energy[:,13], "*")
plt.plot(l_data[:,1], cas_6_11_energy[:,14], "*")
plt.plot(l_data[:,1], cas_6_11_energy[:,15], "*")
plt.plot(l_data[:,1], cas_6_11_energy[:,16], "*")
plt.plot(l_data[:,1], cas_6_11_energy[:,17], "*")
plt.show()

# %% [markdown]
# # Sorting polariton states for the Photon number state QED-CAS(6,11) method

# %%
lp_pn_6_11 = np.copy(pn_6_11_energy[:,10])
#lp_pn_6_11[9:] = np.copy(pn_6_11_energy[9:,9])
up_pn_6_11 = np.copy(pn_6_11_energy[:,11])
up_pn_6_11[3:] = np.copy(pn_6_11_energy[3:,13])
#up_pn_6_11[4:] = np.copy(pn_6_11_energy[4:,16])
up_pn_6_11[5:] = np.copy(pn_6_11_energy[5:,17])

plt.plot(l_data[:,1], pn_6_11_energy[:,0]+omega_6_11)
plt.plot(l_data[:,1], lp_pn_6_11, 'r--')
plt.plot(l_data[:,1], up_pn_6_11, 'r--')
plt.plot(l_data[:,1], pn_6_11_energy[:,11], "*")
plt.plot(l_data[:,1], pn_6_11_energy[:,12], "*")
plt.plot(l_data[:,1], pn_6_11_energy[:,13], "*")
plt.plot(l_data[:,1], pn_6_11_energy[:,14], "*")
plt.plot(l_data[:,1], pn_6_11_energy[:,15], "*")
plt.plot(l_data[:,1], pn_6_11_energy[:,16], "*")
plt.plot(l_data[:,1], pn_6_11_energy[:,17], "*")
plt.show()

# %% [markdown]
# # Sorting polariton states for the Coherent-State QED-CAS(6,7) method

# %%
lp_cas_6_7 = np.copy(cas_6_7_energy[:,10])
lp_cas_6_7[8:] = np.copy(cas_6_7_energy[8:,9])
up_cas_6_7 = np.copy(cas_6_7_energy[:,11])
up_cas_6_7[1:] = np.copy(cas_6_7_energy[1:,14])
up_cas_6_7[3:] = np.copy(cas_6_7_energy[3:,15])
up_cas_6_7[4:] = np.copy(cas_6_7_energy[4:,17])

plt.plot(l_data[:,1], cas_6_7_energy[:,0]+omega_6_7)
#plt.plot(l_data[:,1], lp_cas_6_7, 'r--')
plt.plot(l_data[:,1], up_cas_6_7, 'r--')
#plt.plot(l_data[:,1], cas_6_7_energy[:,9], "*", label='9')
#plt.plot(l_data[:,1], cas_6_7_energy[:,10], "*", label='10')
plt.plot(l_data[:,1], cas_6_7_energy[:,11], "*", label='11')
plt.plot(l_data[:,1], cas_6_7_energy[:,12], "*", label='12')
plt.plot(l_data[:,1], cas_6_7_energy[:,13], "*", label='13')
plt.plot(l_data[:,1], cas_6_7_energy[:,14], "*", label='14')
plt.plot(l_data[:,1], cas_6_7_energy[:,15], "*", label='15')
plt.plot(l_data[:,1], cas_6_7_energy[:,16], "*", label='16')
plt.plot(l_data[:,1], cas_6_7_energy[:,17], "*", label='17')
plt.xlim(-0.001, 0.02)
plt.legend()
plt.show()

# %% [markdown]
# # Sorting polariton states for photon number QED-CAS(6,7) method

# %%
lp_pn_6_7 = np.copy(pn_6_7_energy[:,10])
lp_pn_6_7[7:] = np.copy(pn_6_7_energy[7:,9])
up_pn_6_7 = np.copy(pn_6_7_energy[:,11])
up_pn_6_7[1:] = np.copy(pn_6_7_energy[1:,14])
up_pn_6_7[3:] = np.copy(pn_6_7_energy[3:,15])
up_pn_6_7[4:] = np.copy(pn_6_7_energy[4:,17])

plt.plot(l_data[:,1], pn_6_7_energy[:,0]+omega_6_7)
plt.plot(l_data[:,1], lp_pn_6_7, 'r--')
plt.plot(l_data[:,1], up_pn_6_7, 'r--')
plt.plot(l_data[:,1], pn_6_7_energy[:,9], "*", label='9')
plt.plot(l_data[:,1], pn_6_7_energy[:,10], "*", label='10')
plt.plot(l_data[:,1], pn_6_7_energy[:,11], "*", label='11')
plt.plot(l_data[:,1], pn_6_7_energy[:,12], "*", label='12')
plt.plot(l_data[:,1], pn_6_7_energy[:,13], "*", label='13')
plt.plot(l_data[:,1], pn_6_7_energy[:,14], "*", label='14')
plt.plot(l_data[:,1], pn_6_7_energy[:,15], "*", label='15')
plt.plot(l_data[:,1], pn_6_7_energy[:,16], "*", label='16')
plt.plot(l_data[:,1], pn_6_7_energy[:,17], "*", label='17')
#plt.xlim(-0.001, 0.02)
plt.legend()
plt.show()

# %% [markdown]
# # Sorting polariton states for the Coherent-State QED-FCI method

# %%
lp_fci = np.copy(fci_energy[:,10])
lp_fci[8:] = np.copy(fci_energy[8:,9])

up_fci = np.copy(fci_energy[:,11])
up_fci[3:] = np.copy(fci_energy[3:,13])
up_fci[4:] = np.copy(fci_energy[4:,16])
up_fci[7:] = np.copy(fci_energy[7:,17])


plt.plot(l_data[:,1], fci_energy[:,0]+omega_fci)
plt.plot(l_data[:,1], lp_fci, 'r--')
plt.plot(l_data[:,1], up_fci, 'r--')
plt.plot(l_data[:,1], fci_energy[:,9], '*')
plt.plot(l_data[:,1], fci_energy[:,10], '*')
plt.plot(l_data[:,1], fci_energy[:,11], '*')
plt.plot(l_data[:,1], fci_energy[:,12], '*')
plt.plot(l_data[:,1], fci_energy[:,13], '*')
plt.plot(l_data[:,1], fci_energy[:,14], '*')
plt.plot(l_data[:,1], fci_energy[:,15], '*')
plt.plot(l_data[:,1], fci_energy[:,16], '*')
plt.plot(l_data[:,1], fci_energy[:,17], '*')

# %%
E_min = fci_energy[0,0]
plt.plot(l_data[:,1], (fci_energy[:,0]+omega_fci-E_min)*27.2114, color="black", linestyle="dashed", label="E$_g$ + $\omega$, CS-QEDFCI-1")
plt.plot(l_data[:,1], (lp_fci-E_min)*27.2114,  color="red", marker="o", ms="8", label="E$_{LP}$, CS-QEDFCI-1")
plt.plot(l_data[:,1], (up_fci-E_min)*27.2114,  color="blue", marker="o", ms="8", label="E$_{UP}$, CS-QEDFCI-1")
plt.legend()
plt.xlabel("Coupling Strength (atomic units)")
plt.ylabel("Relative Energy (eV)")
plt.legend()
plt.xlim(0, 0.05)
plt.ylim(12.4, 14.3)
plt.tight_layout()
plt.savefig("BH3_QEDFCI-1.png", dpi=150)
plt.show()

lengend = """QED-FCI/6-31G in the coherent state basis of BH3 coupled to a photon with y-polarization tuned to a transition
with a strong y-component of the transition dipole moment (3rd singlet excited state);   Geometry is optimized at the MP2/6-311G level of theory.
Photon energy is 13.07 eV.
"""
omega_fci * 27.2114
# Out:
# 13.077093472402229

# %%
plt.plot(l_data[:,1], cas_6_11_energy[:,0]+omega_6_11)
plt.plot(l_data[:,1], cas_6_11_energy[:,10])
plt.plot(l_data[:,1], cas_6_11_energy[:,11], '*')
plt.plot(l_data[:,1], cas_6_11_energy[:,13], '*')
plt.plot(l_data[:,1], cas_6_11_energy[:,14], '*')
plt.plot(l_data[:,1], cas_6_11_energy[:,15], '*')
#plt.plot(l_data[:,1], cas_6_7_energy[:,0]+omega_6_7)
#plt.plot(l_data[:,1], cas_6_7_energy[:,10])
#plt.plot(l_data[:,1], cas_6_7_energy[:,11])

#plt.plot(l_data[:,1], cas_6_11_energy[:,0]+omega_6_11)
#plt.plot(l_data[:,1], cas_6_7_energy[:,0]+omega_6_7)

# %%
fci_rabi_splitting = up_fci - lp_fci
cas_6_14_rabi_splitting = up_cas_6_14 - lp_cas_6_14
cas_6_11_rabi_splitting = up_cas_6_11 - lp_cas_6_11
cas_6_7_rabi_splitting = up_cas_6_7 - lp_cas_6_7

pn_6_14_rabi_splitting = up_pn_6_14 - lp_pn_6_14
pn_6_11_rabi_splitting = up_pn_6_11 - lp_pn_6_11
pn_6_7_rabi_splitting = up_pn_6_7 - lp_pn_6_7


#plt.plot(l_data[:,1], fci_rabi_splitting, "red", linestyle="dashed", marker="s", ms="8", mfc="none", label="Minimal Photon Number Basis")
plt.plot(l_data[:,1], (cas_6_14_rabi_splitting-fci_rabi_splitting) * 27.2114, "purple", linestyle="solid", marker="o", ms="7", label="CS-QED-CAS(6,14)-1")
plt.plot(l_data[:,1], (pn_6_14_rabi_splitting-fci_rabi_splitting) * 27.2114, "purple", linestyle="dashed", marker="s", ms="9", mfc="none", label="PN-QED-CAS(6,14)-1")
plt.plot(l_data[:,1], (cas_6_11_rabi_splitting-fci_rabi_splitting)* 27.2114, "blue", linestyle="solid", marker="o", ms="7",label="CS-QED-CAS(6,11)-1")
plt.plot(l_data[:,1], (pn_6_11_rabi_splitting-fci_rabi_splitting) * 27.2114, "blue", linestyle="dashed", marker="s", ms="9", mfc="none", label="PN-QED-CAS(6,11)-1")
plt.plot(l_data[:,1], (cas_6_7_rabi_splitting-fci_rabi_splitting)* 27.2114, "red", linestyle="solid", marker="o", ms="7",  label="CS-QED-CAS(6,7)-1")
plt.plot(l_data[:,1], (pn_6_7_rabi_splitting-fci_rabi_splitting)* 27.2114, "red", linestyle="dashed", marker="s", ms="9", mfc="none", label="PN-QED-CAS(6,7)-1")
plt.yscale("log")
plt.xlim(0.005, 0.05)
plt.ylim(10e-7, 5e-1)
plt.xlabel("Coupling Strength (atomic units)")
plt.ylabel("Rabi Splitting Error (eV)")
plt.legend()
plt.tight_layout()
plt.savefig("BH3_QEDCAS-1_RS.png", dpi=150)
plt.show()

lengend = """Rabis splitting using QED-CAS(n,m)/6-31G in the coherent state basis of BH3 coupled to a photon with y-polarization tuned to a transition
with a strong y-component of the transition dipole moment (3rd singlet excited state); the photon energy is   Geometry is optimized at the MP2/6-311G level of theory.
Photon energy is 13.65 eV for CAS(6,7), 13.25 eV for CAS(6,11), and 13.09 for CAS(6,14).
"""
print(omega_6_7 * 27.2114)
print(omega_6_11 * 27.2114)
print(omega_6_14 * 27.2114)
# Out:
# 13.652913999776798
# 13.258904124397093
# 13.09637363016246

# %%
plt.plot(numph[:_N], np_mae[:_N], "red", linestyle="dashed", marker="s", ms="8", mfc="none", label="Minimal Photon Number Basis")
plt.plot(numph[:_N], cs_mae[:_N], "blue", linestyle="dashed", marker="s", ms="8", mfc="none", label="Mininal Coherent State Basis")
plt.plot(numph[:_N], np_mae10[:_N], "red",  marker="o", ms="8",  label="Converged Photon Number Basis")
plt.plot(numph[:_N], cs_mae10[:_N], "blue",  marker="o", ms="8",  label="Converged Coherent State Basis")
plt.yscale("log")
plt.xlabel("Number of active orbitals")
plt.ylabel("NPE (Hartrees)")
plt.ylim(5e-4, 1e-2)
plt.legend()
plt.tight_layout()
plt.savefig("LiH_npe_vs_nact.png", dpi=150)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plt.plot(numph[:_N], np_mae[:_N], "red", linestyle="dashed", marker="s", ms="8", mfc="none", label="Minimal Photon Number Basis")
#       2 plt.plot(numph[:_N], cs_mae[:_N], "blue", linestyle="dashed", marker="s", ms="8", mfc="none", label="Mininal Coherent State Basis")
#       3 plt.plot(numph[:_N], np_mae10[:_N], "red",  marker="o", ms="8",  label="Converged Photon Number Basis")
#
# NameError: name 'numph' is not defined
