# %%
import numpy as np
from matplotlib import pyplot as plt
import json
import psi4

# %%
subdirname = "/Users/jfoley19/Code/data_repository/Mapol/BH3/qed-ci/sto-3g/"

ref_file = "bh3_qed-fci_sto-3g_coherent_state_basis_5_8_13_omega_0.5522658093047355.json"

ref_data = json.load(open(subdirname + ref_file))

# %%
lam = np.array(ref_data["model"]["lambda"])
print(lam[:,1])
en = np.array(ref_data["return_result"])
# Out:
# [0.    0.005 0.01  0.015 0.02  0.025 0.03  0.035 0.04  0.045 0.05 ]

# %%
plt.plot(lam[:,1], en[:,6])
plt.plot(lam[:,1], en[:,7])
plt.plot(lam[:,1], en[:,0]+0.5522658093047355)
