# %%
import numpy as np
from matplotlib import pyplot as plt
import json
import psi4

# %%
mol_str = """
Li
H 1 1.8
symmetry c1
"""

options_dict = {
    "basis": "6-311g",
    "scf_type": "pk",
    "e_convergence": 1e-10,
    "d_convergence": 1e-10,
    'num_roots' : 5, 
    'active' : 15,
}

mol = psi4.geometry(mol_str)
psi4.set_options(options_dict)
scf_e, wfn = psi4.energy('SCF', return_wfn=True)
fci_energy, wfn = psi4.energy('fci',ref_wfn=wfn, return_wfn=True)
-8.00343748753214
-8.003437487549196


-7.894557152757274
-7.89455715275803
# Out:
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYY31VALT
# *** at Fri Sep  8 15:55:19 2023
#
#    => Loading Basis Set <=
#
#     Name: 6-311G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    41 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-311g.gbs
#     atoms 2 entry H          line    21 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-311g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.226087218223     7.016003436600
#          H            0.000000000000     0.000000000000     1.573912781777     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      5.90416  C =      5.90416 [cm^-1]
#   Rotational constants: A = ************  B = 177002.29231  C = 177002.29231 [MHz]
#   Nuclear repulsion =    0.881962017783333
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-311G
#     Blend: 6-311G
#     Number of shells: 10
#     Number of basis functions: 16
#     Number of Cartesian functions: 16
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              10
#       Number of primitives:             21
#       Number of atomic orbitals:        16
#       Number of basis functions:        16
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 18632 doubles for integral storage.
#   We computed 1540 shell quartets total.
#   Whereas there are 1540 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 4.8006412247E-02.
#   Reciprocal condition number of the overlap matrix is 1.3406065542E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         16      16
#    -------------------------
#     Total      16      16
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.69881729983748   -7.69882e+00   0.00000e+00
#    @RHF iter   1:    -7.96555137325713   -2.66734e-01   6.37720e-03 DIIS/ADIIS
#    @RHF iter   2:    -7.98027805203892   -1.47267e-02   9.26120e-04 DIIS/ADIIS
#    @RHF iter   3:    -7.98085720715626   -5.79155e-04   2.55722e-04 DIIS/ADIIS
#    @RHF iter   4:    -7.98092269891499   -6.54918e-05   7.05612e-05 DIIS
#    @RHF iter   5:    -7.98092963751301   -6.93860e-06   1.02890e-05 DIIS
#    @RHF iter   6:    -7.98092975916295   -1.21650e-07   8.78911e-07 DIIS
#    @RHF iter   7:    -7.98092976019629   -1.03334e-09   4.60581e-08 DIIS
#    @RHF iter   8:    -7.98092976019807   -1.77103e-12   7.04063e-09 DIIS
#    @RHF iter   9:    -7.98092976019811   -4.44089e-14   7.96530e-10 DIIS
#    @RHF iter  10:    -7.98092976019811    2.66454e-15   1.24703e-10 DIIS
#    @RHF iter  11:    -7.98092976019810    2.66454e-15   1.46545e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.468173     2A     -0.290929
#
#     Virtual:
#
#        3A     -0.004981     4A      0.040019     5A      0.040019
#        6A      0.091613     7A      0.111800     8A      0.146930
#        9A      0.146930    10A      0.220266    11A      0.531297
#       12A      0.573831    13A      0.573831    14A      0.643208
#       15A      2.816030    16A      3.954297
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.98092976019810
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.8819620177833333
#     One-Electron Energy =                 -12.2075805849036243
#     Two-Electron Energy =                   3.3446888069221865
#     Total Energy =                         -7.9809297601981042
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -4.2583751            1.6925353           -2.5658398
#  Magnitude           :                                                    2.5658398
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYY31VALT at Fri Sep  8 15:55:19 2023
# Module time:
# 	user time   =       0.12 seconds =       0.00 minutes
# 	system time =       0.05 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.12 seconds =       0.00 minutes
# 	system time =       0.05 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
#
# Scratch directory: /tmp/
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              10
#       Number of SO shells:              10
#       Number of primitives:             21
#       Number of atomic orbitals:        16
#       Number of basis functions:        16
#
#       Number of irreps:                  1
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  16 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 2701 non-zero two-electron integrals.
#         Stored in file 33.
#
#
#          ---------------------------------------------------------
#                           Configuration Interaction
#                             (a 'D E T C I' module)
#
#                  C. David Sherrill, Daniel G. A. Smith, and
#                               Matt L. Leininger
#          ---------------------------------------------------------
#
#
#    ==> Parameters <==
#
#     EX LEVEL       =        4      H0 BLOCKSIZE  =     1000
#     VAL EX LEVEL   =        0      H0 GUESS SIZE =     1000
#     H0COUPLINGSIZE =        0      H0 COUPLING   =       NO
#     MAXITER        =       24      NUM PRINT     =       20
#     NUM ROOTS      =        5      ICORE         =        1
#     PRINT LVL      =        1      FCI           =      YES
#     R CONV         = 1.00e-04      MIXED         =      YES
#     E CONV         = 1.00e-10      MIXED4        =      YES
#     R4S            =       NO      REPL OTF      =       NO
#     DIAG METHOD    =      SEM      FOLLOW ROOT   =        0
#     PRECONDITIONER = DAVIDSON      UPDATE        = DAVIDSON
#     S              =   0.0000      Ms0           =      YES
#     GUESS VECTOR   =  H0BLOCK      OPENTYPE      =     NONE
#     COLLAPSE SIZE  =        1      HD AVG        = EVANGELISTI
#     MAX NUM VECS   =      125      REF SYM       =     AUTO
#     IOPEN        =       NO
#
#     EX ALLOW       =  1  1  1  1
#     STATE AVERAGE  =  0(1.00)
#
#    ==> CI Orbital and Space information <==
#
#    ------------------------------------
#                Space    Total     A
#    ------------------------------------
#                  Nso       16    16
#                  Nmo       16    16
#                Ndocc        2     2
#                Nsocc        0     0
#    ------------------------------------
#               CI Spaces
#    ------------------------------------
#         Dropped DOCC        0     0
#               Active       15    15
#         Dropped UOCC        1     1
#    ------------------------------------
#
#    ==> Setting up CI strings <==
#
#     There are 105 alpha and 105 beta strings
#     The CI space requires 11025 (1.10E+04) determinants and 1 blocks
#
#    ==> Transforming CI integrals <==
#
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
#
#    ==> Starting CI iterations <==
#
#     H0 Block Eigenvalue =  -8.00030003
#
#     Simultaneous Expansion Method (Block Davidson Method)
#     Using 5 initial trial vectors
#
# (sem_iter): H0block_->H0b_diag[1][1] - H0block_->H0b_diag[2][1] = 0.616719 - -0.616719 = 1.233439 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[3][3] - H0block_->H0b_diag[5][3] = 0.586924 - -0.586924 = 1.173848 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[3][4] - H0block_->H0b_diag[5][4] = -0.087869 - 0.087869 = -0.175738 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[1][7] - H0block_->H0b_diag[2][7] = -0.126429 - 0.126429 = -0.252859 > 1.0E-8
#      Iter   Root       Total Energy       Delta E      C RMS
#
#    @CI  0:     0     -8.000300028112   -8.8823E+00   1.1860E-01
#    @CI  0:     1     -7.892950686007   -8.7749E+00   8.9317E-02
#    @CI  0:     2     -7.856773174791   -8.7387E+00   7.9626E-02
#    @CI  0:     3     -7.856773174790   -8.7387E+00   7.9626E-02
#    @CI  0:     4     -7.785910106675   -8.6679E+00   9.1231E-02
#
#    @CI  1:     0     -8.003385123959   -3.0851E-03   1.2093E-02
#    @CI  1:     1     -7.894531694222   -1.5810E-03   8.8227E-03
#    @CI  1:     2     -7.857934062949   -1.1609E-03   7.0366E-03
#    @CI  1:     3     -7.857934062948   -1.1609E-03   7.0366E-03
#    @CI  1:     4     -7.787589051082   -1.6789E-03   8.6095E-03
#
#    @CI  2:     0     -8.003436173725   -5.1050E-05   1.8883E-03
#    @CI  2:     1     -7.894555564124   -2.3870E-05   1.7694E-03
#    @CI  2:     2     -7.857946302783   -1.2240E-05   1.3118E-03
#    @CI  2:     3     -7.857946302782   -1.2240E-05   1.3118E-03
#    @CI  2:     4     -7.787614332685   -2.5282E-05   1.5585E-03
#
#    @CI  3:     0     -8.003437407629   -1.2339E-06   4.4661E-04
#    @CI  3:     1     -7.894556863329   -1.2992E-06   6.3013E-04
#    @CI  3:     2     -7.857946757397   -4.5461E-07   2.4916E-04
#    @CI  3:     3     -7.857946757396   -4.5461E-07   2.4916E-04
#    @CI  3:     4     -7.787615469253   -1.1366E-06   6.8861E-04
#
#    @CI  4:     0     -8.003437484220   -7.6591E-08   1.0024E-04
#    @CI  4:     1     -7.894557126523   -2.6319E-07   2.7592E-04
#    @CI  4:     2     -7.857946800283   -4.2886E-08   1.6683E-04
#    @CI  4:     3     -7.857946800283   -4.2886E-08   1.6683E-04
#    @CI  4:     4     -7.787616325297   -8.5604E-07   1.0096E-03
#
#    @CI  5:     0     -8.003437487406   -3.1859E-09   2.1893E-05
#    @CI  5:     1     -7.894557151504   -2.4982E-08   6.2375E-05
#    @CI  5:     2     -7.857946813768   -1.3485E-08   6.9255E-05
#    @CI  5:     3     -7.857946813767   -1.3485E-08   6.9255E-05
#    @CI  5:     4     -7.787617184364   -8.5907E-07   5.5383E-04
#
#    @CI  6:     0     -8.003437487544   -1.3807E-10   4.2778E-06
#    @CI  6:     1     -7.894557152688   -1.1838E-09   1.3206E-05
#    @CI  6:     2     -7.857946815705   -1.9373E-09   2.4427E-05
#    @CI  6:     3     -7.857946815705   -1.9373E-09   2.4427E-05
#    @CI  6:     4     -7.787617396181   -2.1182E-07   2.4956E-04
#
#    @CI  7:     0     -8.003437487549   -5.1994E-12   9.2964E-07 c
#    @CI  7:     1     -7.894557152757   -6.8667E-11   3.9072E-06 c
#    @CI  7:     2     -7.857946815912   -2.0673E-10   7.5427E-06
#    @CI  7:     3     -7.857946815911   -2.0674E-10   7.5427E-06
#    @CI  7:     4     -7.787617421335   -2.5154E-08   6.3156E-05
#
#    @CI  8:     0     -8.003437487549   1.4211E-14   9.4447E-07 c
#    @CI  8:     1     -7.894557152757   -3.1086E-13   3.9865E-06 c
#    @CI  8:     2     -7.857946815925   -1.3648E-11   1.5590E-06 c
#    @CI  8:     3     -7.857946815925   -1.3632E-11   1.5590E-06 c
#    @CI  8:     4     -7.787617422551   -1.2159E-09   1.3311E-05
#
#    @CI  9:     0     -8.003437487549   -2.1316E-14   8.9467E-07 c
#    @CI  9:     1     -7.894557152757   -2.1849E-13   3.7027E-06 c
#    @CI  9:     2     -7.857946815925   1.7764E-15   1.5590E-06 c
#    @CI  9:     3     -7.857946815925   -1.9540E-14   1.5590E-06 c
#    @CI  9:     4     -7.787617422597   -4.5874E-11   2.6677E-06 c
#
#
#    ==> Energetics <==
#
#     SCF energy =           -7.980929760198104
#     Total CI energy =      -8.003437487549196
#
#    ==> FCI root 0 information <==
#
#     FCI Root 0 energy =    -8.003437487549196
#
#    The 20 most important determinants:
#
#     *   1   -0.983598  (    0,    0)  1AX 2AX
#     *   2    0.056846  (   36,   36)  1AX 10AX
#     *   3    0.049774  (   78,   78)  1AX 14AX
#     *   4    0.042015  (   78,   36)  1AX 10AB 14AA
#     *   5    0.042015  (   36,   78)  1AX 10AA 14AB
#     *   6   -0.040900  (    1,    0)  1AX 2AB 3AA
#     *   7   -0.040900  (    0,    1)  1AX 2AA 3AB
#     *   8    0.038153  (   10,   10)  1AX 6AX
#     *   9    0.035156  (   78,   10)  1AX 6AB 14AA
#     *  10    0.035156  (   10,   78)  1AX 6AA 14AB
#     *  11    0.031949  (    1,   36)  1AX 3AA 10AB
#     *  12    0.031949  (   36,    1)  1AX 3AB 10AA
#     *  13    0.031840  (    1,   78)  1AX 3AA 14AB
#     *  14    0.031840  (   78,    1)  1AX 3AB 14AA
#     *  15    0.031194  (   45,   45)  1AX 11AX
#     *  16    0.030827  (    1,   10)  1AX 3AA 6AB
#     *  17    0.030827  (   10,    1)  1AX 3AB 6AA
#     *  18    0.027306  (   10,   36)  1AX 6AA 10AB
#     *  19    0.027306  (   36,   10)  1AX 6AB 10AA
#     *  20    0.027057  (    1,    1)  1AX 3AX
#
#
#    ==> FCI root 1 information <==
#
#     FCI Root 1 energy =    -7.894557152757274
#
#    The 20 most important determinants:
#
#     *   1   -0.630085  (    0,    1)  1AX 2AA 3AB
#     *   2   -0.630085  (    1,    0)  1AX 2AB 3AA
#     *   3   -0.186991  (    0,   15)  1AX 2AA 7AB
#     *   4   -0.186991  (   15,    0)  1AX 2AB 7AA
#     *   5    0.160370  (    1,    1)  1AX 3AX
#     *   6    0.113837  (   10,    1)  1AX 3AB 6AA
#     *   7    0.113837  (    1,   10)  1AX 3AA 6AB
#     *   8    0.098356  (   78,    1)  1AX 3AB 14AA
#     *   9    0.098356  (    1,   78)  1AX 3AA 14AB
#     *  10    0.093865  (   36,    1)  1AX 3AB 10AA
#     *  11    0.093865  (    1,   36)  1AX 3AA 10AB
#     *  12    0.088069  (    0,    0)  1AX 2AX
#     *  13   -0.086579  (    0,   10)  1AX 2AA 6AB
#     *  14   -0.086579  (   10,    0)  1AX 2AB 6AA
#     *  15    0.063442  (   45,    1)  1AX 3AB 11AA
#     *  16    0.063442  (    1,   45)  1AX 3AA 11AB
#     *  17    0.035293  (   78,    0)  1AX 2AB 14AA
#     *  18    0.035293  (    0,   78)  1AX 2AA 14AB
#     *  19    0.034925  (   78,   15)  1AX 7AB 14AA
#     *  20    0.034925  (   15,   78)  1AX 7AA 14AB
#
#
#    ==> FCI root 2 information <==
#
#     FCI Root 2 energy =    -7.857946815925397
#
#    The 20 most important determinants:
#
#     *   1   -0.603156  (    0,    3)  1AX 2AA 4AB
#     *   2   -0.603156  (    3,    0)  1AX 2AB 4AA
#     *   3   -0.281943  (    0,   21)  1AX 2AA 8AB
#     *   4   -0.281943  (   21,    0)  1AX 2AB 8AA
#     *   5    0.105365  (   10,    3)  1AX 4AB 6AA
#     *   6    0.105365  (    3,   10)  1AX 4AA 6AB
#     *   7    0.101505  (   78,    3)  1AX 4AB 14AA
#     *   8    0.101505  (    3,   78)  1AX 4AA 14AB
#     *   9    0.091138  (   36,    3)  1AX 4AB 10AA
#     *  10    0.091138  (    3,   36)  1AX 4AA 10AB
#     *  11    0.082511  (    1,    3)  1AX 3AA 4AB
#     *  12    0.082511  (    3,    1)  1AX 3AB 4AA
#     *  13    0.066970  (   45,    3)  1AX 4AB 11AA
#     *  14    0.066970  (    3,   45)  1AX 4AA 11AB
#     *  15    0.060270  (   36,   21)  1AX 8AB 10AA
#     *  16    0.060270  (   21,   36)  1AX 8AA 10AB
#     *  17    0.053534  (   78,   21)  1AX 8AB 14AA
#     *  18    0.053534  (   21,   78)  1AX 8AA 14AB
#     *  19    0.049998  (   10,   21)  1AX 6AA 8AB
#     *  20    0.049998  (   21,   10)  1AX 6AB 8AA
#
#
#    ==> FCI root 3 information <==
#
#     FCI Root 3 energy =    -7.857946815925009
#
#    The 20 most important determinants:
#
#     *   1    0.603156  (    6,    0)  1AX 2AB 5AA
#     *   2    0.603156  (    0,    6)  1AX 2AA 5AB
#     *   3    0.281943  (   28,    0)  1AX 2AB 9AA
#     *   4    0.281943  (    0,   28)  1AX 2AA 9AB
#     *   5   -0.105365  (    6,   10)  1AX 5AA 6AB
#     *   6   -0.105365  (   10,    6)  1AX 5AB 6AA
#     *   7   -0.101505  (    6,   78)  1AX 5AA 14AB
#     *   8   -0.101505  (   78,    6)  1AX 5AB 14AA
#     *   9   -0.091138  (    6,   36)  1AX 5AA 10AB
#     *  10   -0.091138  (   36,    6)  1AX 5AB 10AA
#     *  11   -0.082511  (    6,    1)  1AX 3AB 5AA
#     *  12   -0.082511  (    1,    6)  1AX 3AA 5AB
#     *  13   -0.066970  (    6,   45)  1AX 5AA 11AB
#     *  14   -0.066970  (   45,    6)  1AX 5AB 11AA
#     *  15   -0.060270  (   28,   36)  1AX 9AA 10AB
#     *  16   -0.060270  (   36,   28)  1AX 9AB 10AA
#     *  17   -0.053534  (   28,   78)  1AX 9AA 14AB
#     *  18   -0.053534  (   78,   28)  1AX 9AB 14AA
#     *  19   -0.049998  (   28,   10)  1AX 6AB 9AA
#     *  20   -0.049998  (   10,   28)  1AX 6AA 9AB
#
#
#    ==> FCI root 4 information <==
#
#     FCI Root 4 energy =    -7.787617422596609
#
#    The 20 most important determinants:
#
#     *   1    0.503285  (   10,    0)  1AX 2AB 6AA
#     *   2    0.503285  (    0,   10)  1AX 2AA 6AB
#     *   3   -0.435340  (    0,   15)  1AX 2AA 7AB
#     *   4   -0.435340  (   15,    0)  1AX 2AB 7AA
#     *   5   -0.166178  (   10,   10)  1AX 6AX
#     *   6    0.080397  (   10,   15)  1AX 6AA 7AB
#     *   7    0.080397  (   15,   10)  1AX 6AB 7AA
#     *   8    0.071544  (   78,   15)  1AX 7AB 14AA
#     *   9    0.071544  (   15,   78)  1AX 7AA 14AB
#     *  10   -0.067268  (   10,   78)  1AX 6AA 14AB
#     *  11   -0.067268  (   78,   10)  1AX 6AB 14AA
#     *  12   -0.067103  (   10,    1)  1AX 3AB 6AA
#     *  13   -0.067103  (    1,   10)  1AX 3AA 6AB
#     *  14   -0.059619  (    0,   36)  1AX 2AA 10AB
#     *  15   -0.059619  (   36,    0)  1AX 2AB 10AA
#     *  16   -0.058855  (   10,   45)  1AX 6AA 11AB
#     *  17   -0.058855  (   45,   10)  1AX 6AB 11AA
#     *  18    0.055904  (   36,   15)  1AX 7AB 10AA
#     *  19    0.055904  (   15,   36)  1AX 7AA 10AB
#     *  20    0.055001  (    1,   15)  1AX 3AA 7AB
#
# 		 "A good bug is a dead bug"
#
# 			 - Starship Troopers
#
# 		 "I didn't write FORTRAN.  That's the problem."
#
# 			 - Edward Valeev

# %%
dict = {'repo': {'repository_url': 'https://github.com/mapol-chem/qed-ci', 'branch': 'direct_ci', 'commit': '7f25d1c5fd458a06002e79d610aa17399f213f71'}, 'molecule': {'molecule_name': 'MgH', 'geometry': [], 'symbols': ['Mg', 'H'], 'bond_length': [1.25]}, 'driver': 'energy', 'model': {'method': 'qed-cas', 'orbital_basis': 'cc-pVDZ', 'photon_basis': 'photon_number_basis', 'number_of_photon_states': 0, 'nact_orbs': 10, 'nact_els': 12, 'lambda': [0, 0, 0], 'omega': 0}, 'return_result': [[-199.84574777281213, -199.6670949142944, -199.62808625455398, -199.57617130672267, -199.57617130672236, -199.55530455621442, -199.55530455621357, -199.45881726211363, -199.43159507651913, -199.10130572148347]]}

# %%
json_object = json.dumps(dict, indent=4)
with open("test.json", "w") as outfile:
    outfile.write(json_object)

# %%
mol_tmpl = """
Li
H 1 **R**
symmetry c1
"""

r_data = np.linspace(1.4, 2.2, 50)

fci_e0 = []
fci_e1 = []
fci_e2 = []
for r in r_data:
    mol_str = mol_tmpl.replace("**R**", str(r))
    mol = psi4.geometry(mol_str)
    scf_e, wfn = psi4.energy('SCF', return_wfn=True)
    fci_energy, wfn = psi4.energy('fci',ref_wfn=wfn, return_wfn=True)
    fci_e0.append(wfn.variable("CI ROOT 0 TOTAL ENERGY"))
    fci_e1.append(wfn.variable("CI ROOT 1 TOTAL ENERGY"))
    fci_e2.append(wfn.variable("CI ROOT 2 TOTAL ENERGY"))
# Out:
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYY31VALT
# *** at Fri Sep  8 11:48:48 2023
#
#    => Loading Basis Set <=
#
#     Name: 6-311G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    41 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-311g.gbs
#     atoms 2 entry H          line    21 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-311g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.175845614173     7.016003436600
#          H            0.000000000000     0.000000000000     1.224154385827     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      9.75994  C =      9.75994 [cm^-1]
#   Rotational constants: A = ************  B = 292595.62606  C = 292595.62606 [MHz]
#   Nuclear repulsion =    1.133951165721429
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-311G
#     Blend: 6-311G
#     Number of shells: 10
#     Number of basis functions: 16
#     Number of Cartesian functions: 16
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              10
#       Number of primitives:             21
#       Number of atomic orbitals:        16
#       Number of basis functions:        16
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 18632 doubles for integral storage.
#   We computed 1540 shell quartets total.
#   Whereas there are 1540 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 2.5757620281E-02.
#   Reciprocal condition number of the overlap matrix is 6.8723139727E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         16      16
#    -------------------------
#     Total      16      16
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.71034675340069   -7.71035e+00   0.00000e+00
#    @RHF iter   1:    -7.96505451638544   -2.54708e-01   6.85675e-03 DIIS/ADIIS
#    @RHF iter   2:    -7.97762518864260   -1.25707e-02   8.37170e-04 DIIS/ADIIS
#    @RHF iter   3:    -7.97800197672262   -3.76788e-04   2.00748e-04 DIIS/ADIIS
#    @RHF iter   4:    -7.97803638417315   -3.44075e-05   5.53476e-05 DIIS
#    @RHF iter   5:    -7.97804016029189   -3.77612e-06   9.06022e-06 DIIS
#    @RHF iter   6:    -7.97804025336975   -9.30779e-08   7.57557e-07 DIIS
#    @RHF iter   7:    -7.97804025400433   -6.34587e-10   3.52238e-08 DIIS
#    @RHF iter   8:    -7.97804025400505   -7.19425e-13   3.87817e-09 DIIS
#    @RHF iter   9:    -7.97804025400507   -2.04281e-14   5.94761e-10 DIIS
#    @RHF iter  10:    -7.97804025400506    9.76996e-15   5.52840e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.434464     2A     -0.311927
#
#     Virtual:
#
#        3A      0.002514     4A      0.043453     5A      0.043453
#        6A      0.089407     7A      0.121187     8A      0.154364
#        9A      0.154364    10A      0.237305    11A      0.510275
#       12A      0.591642    13A      0.591642    14A      0.742477
#       15A      2.852144    16A      4.003247
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.97804025400506
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.1339511657214287
#     One-Electron Energy =                 -12.7312005072837540
#     Two-Electron Energy =                   3.6192090875572607
#     Total Energy =                         -7.9780402540050641
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -3.5176173            1.3164164           -2.2012009
#  Magnitude           :                                                    2.2012009
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYY31VALT at Fri Sep  8 11:48:48 2023
# Module time:
# 	user time   =       0.07 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       1.15 seconds =       0.02 minutes
# 	system time =       0.36 seconds =       0.01 minutes
# 	total time  =         15 seconds =       0.25 minutes
#
# Scratch directory: /tmp/
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              10
#       Number of SO shells:              10
#       Number of primitives:             21
#       Number of atomic orbitals:        16
#       Number of basis functions:        16
#
#       Number of irreps:                  1
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  16 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 2701 non-zero two-electron integrals.
#         Stored in file 33.
#
#
#          ---------------------------------------------------------
#                           Configuration Interaction
#                             (a 'D E T C I' module)
#
#                  C. David Sherrill, Daniel G. A. Smith, and
#                               Matt L. Leininger
#          ---------------------------------------------------------
#
#
#    ==> Parameters <==
#
#     EX LEVEL       =        4      H0 BLOCKSIZE  =     1000
#     VAL EX LEVEL   =        0      H0 GUESS SIZE =     1000
#     H0COUPLINGSIZE =        0      H0 COUPLING   =       NO
#     MAXITER        =       24      NUM PRINT     =       20
#     NUM ROOTS      =        5      ICORE         =        1
#     PRINT LVL      =        1      FCI           =      YES
#     R CONV         = 1.00e-04      MIXED         =      YES
#     E CONV         = 1.00e-10      MIXED4        =      YES
#     R4S            =       NO      REPL OTF      =       NO
#     DIAG METHOD    =      SEM      FOLLOW ROOT   =        0
#     PRECONDITIONER = DAVIDSON      UPDATE        = DAVIDSON
#     S              =   0.0000      Ms0           =      YES
#     GUESS VECTOR   =  H0BLOCK      OPENTYPE      =     NONE
#     COLLAPSE SIZE  =        1      HD AVG        = EVANGELISTI
#     MAX NUM VECS   =      125      REF SYM       =     AUTO
#     IOPEN        =       NO
#
#     EX ALLOW       =  1  1  1  1
#     STATE AVERAGE  =  0(1.00)
#
#    ==> CI Orbital and Space information <==
#
#    ------------------------------------
#                Space    Total     A
#    ------------------------------------
#                  Nso       16    16
#                  Nmo       16    16
#                Ndocc        2     2
#                Nsocc        0     0
#    ------------------------------------
#               CI Spaces
#    ------------------------------------
#         Dropped DOCC        0     0
#               Active       16    16
#         Dropped UOCC        0     0
#    ------------------------------------
#
#    ==> Setting up CI strings <==
#
#     There are 120 alpha and 120 beta strings
#     The CI space requires 14400 (1.44E+04) determinants and 1 blocks
#
#    ==> Transforming CI integrals <==
#
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
#
#    ==> Starting CI iterations <==
#
#     H0 Block Eigenvalue =  -7.99451142
#
#     Simultaneous Expansion Method (Block Davidson Method)
#     Using 5 initial trial vectors
#
# (sem_iter): H0block_->H0b_diag[1][1] - H0block_->H0b_diag[2][1] = -0.614740 - 0.614740 = -1.229479 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[3][3] - H0block_->H0b_diag[5][3] = -0.579319 - 0.579319 = -1.158639 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[3][4] - H0block_->H0b_diag[5][4] = 0.016469 - -0.016469 = 0.032937 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[1][7] - H0block_->H0b_diag[2][7] = 0.106493 - -0.106493 = 0.212986 > 1.0E-8
#      Iter   Root       Total Energy       Delta E      C RMS
#
#    @CI  0:     0     -7.994511416577   -9.1285E+00   3.9917E-01
#    @CI  0:     1     -7.870376697921   -9.0043E+00   3.8781E-01
#    @CI  0:     2     -7.832918718557   -8.9669E+00   3.8724E-01
#    @CI  0:     3     -7.832918718556   -8.9669E+00   3.8724E-01
#    @CI  0:     4     -7.769004335442   -8.9030E+00   3.8822E-01
#
#    @CI  1:     0     -8.012072149386   -1.7561E-02   2.5855E-02
#    @CI  1:     1     -7.885854237385   -1.5478E-02   2.0729E-02
#    @CI  1:     2     -7.848414851217   -1.5496E-02   2.0395E-02
#    @CI  1:     3     -7.848414851216   -1.5496E-02   2.0395E-02
#    @CI  1:     4     -7.784516489610   -1.5512E-02   2.1021E-02
#
#    @CI  2:     0     -8.012191542333   -1.1939E-04   4.1820E-03
#    @CI  2:     1     -7.885931907882   -7.7670E-05   3.3987E-03
#    @CI  2:     2     -7.848496750253   -8.1899E-05   4.0574E-03
#    @CI  2:     3     -7.848496750252   -8.1899E-05   4.0574E-03
#    @CI  2:     4     -7.784596666099   -8.0176E-05   3.4346E-03
#
#    @CI  3:     0     -8.012194657917   -3.1156E-06   6.1878E-04
#    @CI  3:     1     -7.885935207925   -3.3000E-06   1.1154E-03
#    @CI  3:     2     -7.848506851583   -1.0101E-05   2.9789E-03
#    @CI  3:     3     -7.848506851582   -1.0101E-05   2.9789E-03
#    @CI  3:     4     -7.784599133920   -2.4678E-06   7.1369E-04
#
#    @CI  4:     0     -8.012194750638   -9.2720E-08   1.7453E-04
#    @CI  4:     1     -7.885935808347   -6.0042E-07   6.8395E-04
#    @CI  4:     2     -7.848510408547   -3.5570E-06   1.3748E-03
#    @CI  4:     3     -7.848510408546   -3.5570E-06   1.3748E-03
#    @CI  4:     4     -7.784599290637   -1.5672E-07   3.3313E-04
#
#    @CI  5:     0     -8.012194757831   -7.1932E-09   3.7496E-05
#    @CI  5:     1     -7.885935950108   -1.4176E-07   1.8909E-04
#    @CI  5:     2     -7.848510854206   -4.4566E-07   2.8338E-04
#    @CI  5:     3     -7.848510854205   -4.4566E-07   2.8338E-04
#    @CI  5:     4     -7.784599340398   -4.9761E-08   1.5941E-04
#
#    @CI  6:     0     -8.012194758162   -3.3126E-10   9.6378E-06
#    @CI  6:     1     -7.885935958623   -8.5159E-09   5.2931E-05
#    @CI  6:     2     -7.848510872462   -1.8256E-08   7.1653E-05
#    @CI  6:     3     -7.848510872461   -1.8256E-08   7.1653E-05
#    @CI  6:     4     -7.784599351372   -1.0974E-08   8.6405E-05
#
#    @CI  7:     0     -8.012194758185   -2.3105E-11   2.4327E-06 c
#    @CI  7:     1     -7.885935959388   -7.6445E-10   1.5019E-05
#    @CI  7:     2     -7.848510873754   -1.2925E-09   1.9041E-05
#    @CI  7:     3     -7.848510873753   -1.2925E-09   1.9041E-05
#    @CI  7:     4     -7.784599354313   -2.9418E-09   4.2255E-05
#
#    @CI  8:     0     -8.012194758186   -6.8034E-13   1.6743E-06 c
#    @CI  8:     1     -7.885935959440   -5.1863E-11   3.5188E-06 c
#    @CI  8:     2     -7.848510873831   -7.6982E-11   4.5734E-06 c
#    @CI  8:     3     -7.848510873830   -7.6991E-11   4.5734E-06 c
#    @CI  8:     4     -7.784599354919   -6.0519E-10   1.8618E-05
#
#    @CI  9:     0     -8.012194758186   -3.3218E-13   1.5354E-06 c
#    @CI  9:     1     -7.885935959442   -2.1085E-12   2.3581E-06 c
#    @CI  9:     2     -7.848510873831   -1.7764E-15   4.5734E-06 c
#    @CI  9:     3     -7.848510873830   -1.7764E-15   4.5734E-06 c
#    @CI  9:     4     -7.784599355049   -1.3038E-10   8.0244E-06
#
#    @CI 10:     0     -8.012194758186   -3.7303E-14   1.4904E-06 c
#    @CI 10:     1     -7.885935959442   -1.5987E-14   2.3394E-06 c
#    @CI 10:     2     -7.848510873831   8.8818E-15   4.5734E-06 c
#    @CI 10:     3     -7.848510873830   8.8818E-15   4.5734E-06 c
#    @CI 10:     4     -7.784599355065   -1.6160E-11   2.4079E-06 c
#
#
#    ==> Energetics <==
#
#     SCF energy =           -7.978040254005064
#     Total CI energy =      -8.012194758186146
#
#    ==> FCI root 0 information <==
#
#     FCI Root 0 energy =    -8.012194758186146
#
#    The 20 most important determinants:
#
#     *   1    0.987765  (    0,    0)  1AX 2AX
#     *   2   -0.044048  (   45,   45)  1AX 11AX
#     *   3   -0.040655  (   78,   78)  1AX 14AX
#     *   4   -0.037688  (   36,   36)  1AX 10AX
#     *   5    0.034594  (   78,   36)  1AX 10AB 14AA
#     *   6    0.034594  (   36,   78)  1AX 10AA 14AB
#     *   7   -0.031572  (  106,  106)  2AX 16AX
#     *   8   -0.030514  (   10,   10)  1AX 6AX
#     *   9    0.030390  (   45,   10)  1AX 6AB 11AA
#     *  10    0.030390  (   10,   45)  1AX 6AA 11AB
#     *  11    0.029023  (    0,    1)  1AX 2AA 3AB
#     *  12    0.029023  (    1,    0)  1AX 2AB 3AA
#     *  13   -0.024727  (   78,   10)  1AX 6AB 14AA
#     *  14   -0.024727  (   10,   78)  1AX 6AA 14AB
#     *  15    0.022901  (   78,    1)  1AX 3AB 14AA
#     *  16    0.022901  (    1,   78)  1AX 3AA 14AB
#     *  17   -0.022814  (   36,    1)  1AX 3AB 10AA
#     *  18   -0.022814  (    1,   36)  1AX 3AA 10AB
#     *  19    0.022280  (   10,    1)  1AX 3AB 6AA
#     *  20    0.022280  (    1,   10)  1AX 3AA 6AB
#
#
#    ==> FCI root 1 information <==
#
#     FCI Root 1 energy =    -7.885935959441918
#
#    The 20 most important determinants:
#
#     *   1    0.625977  (    1,    0)  1AX 2AB 3AA
#     *   2    0.625977  (    0,    1)  1AX 2AA 3AB
#     *   3    0.224638  (   15,    0)  1AX 2AB 7AA
#     *   4    0.224638  (    0,   15)  1AX 2AA 7AB
#     *   5   -0.136523  (    1,    1)  1AX 3AX
#     *   6    0.095771  (    1,   10)  1AX 3AA 6AB
#     *   7    0.095771  (   10,    1)  1AX 3AB 6AA
#     *   8   -0.089257  (    1,   36)  1AX 3AA 10AB
#     *   9   -0.089257  (   36,    1)  1AX 3AB 10AA
#     *  10    0.083436  (    1,   78)  1AX 3AA 14AB
#     *  11    0.083436  (   78,    1)  1AX 3AB 14AA
#     *  12   -0.074306  (   10,    0)  1AX 2AB 6AA
#     *  13   -0.074306  (    0,   10)  1AX 2AA 6AB
#     *  14   -0.072428  (    1,   45)  1AX 3AA 11AB
#     *  15   -0.072428  (   45,    1)  1AX 3AB 11AA
#     *  16   -0.063796  (    0,    0)  1AX 2AX
#     *  17    0.052361  (   36,    0)  1AX 2AB 10AA
#     *  18    0.052361  (    0,   36)  1AX 2AA 10AB
#     *  19   -0.035128  (   15,   36)  1AX 7AA 10AB
#     *  20   -0.035128  (   36,   15)  1AX 7AB 10AA
#
#
#    ==> FCI root 2 information <==
#
#     FCI Root 2 energy =    -7.848510873831472
#
#    The 20 most important determinants:
#
#     *   1    0.595974  (    0,    6)  1AX 2AA 5AB
#     *   2    0.595974  (    6,    0)  1AX 2AB 5AA
#     *   3    0.302678  (    0,   28)  1AX 2AA 9AB
#     *   4    0.302678  (   28,    0)  1AX 2AB 9AA
#     *   5    0.090506  (   10,    6)  1AX 5AB 6AA
#     *   6    0.090506  (    6,   10)  1AX 5AA 6AB
#     *   7   -0.083664  (   36,    6)  1AX 5AB 10AA
#     *   8   -0.083664  (    6,   36)  1AX 5AA 10AB
#     *   9    0.082965  (   78,    6)  1AX 5AB 14AA
#     *  10    0.082965  (    6,   78)  1AX 5AA 14AB
#     *  11   -0.077710  (   45,    6)  1AX 5AB 11AA
#     *  12   -0.077710  (    6,   45)  1AX 5AA 11AB
#     *  13   -0.074619  (    0,    3)  1AX 2AA 4AB
#     *  14   -0.074619  (    3,    0)  1AX 2AB 4AA
#     *  15   -0.070724  (    1,    6)  1AX 3AA 5AB
#     *  16   -0.070724  (    6,    1)  1AX 3AB 5AA
#     *  17   -0.056164  (   36,   28)  1AX 9AB 10AA
#     *  18   -0.056164  (   28,   36)  1AX 9AA 10AB
#     *  19    0.048864  (   78,   28)  1AX 9AB 14AA
#     *  20    0.048864  (   28,   78)  1AX 9AA 14AB
#
#
#    ==> FCI root 3 information <==
#
#     FCI Root 3 energy =    -7.848510873830399
#
#    The 20 most important determinants:
#
#     *   1   -0.595974  (    3,    0)  1AX 2AB 4AA
#     *   2   -0.595974  (    0,    3)  1AX 2AA 4AB
#     *   3   -0.302678  (   21,    0)  1AX 2AB 8AA
#     *   4   -0.302678  (    0,   21)  1AX 2AA 8AB
#     *   5   -0.090506  (    3,   10)  1AX 4AA 6AB
#     *   6   -0.090506  (   10,    3)  1AX 4AB 6AA
#     *   7    0.083664  (    3,   36)  1AX 4AA 10AB
#     *   8    0.083664  (   36,    3)  1AX 4AB 10AA
#     *   9   -0.082965  (    3,   78)  1AX 4AA 14AB
#     *  10   -0.082965  (   78,    3)  1AX 4AB 14AA
#     *  11    0.077710  (    3,   45)  1AX 4AA 11AB
#     *  12    0.077710  (   45,    3)  1AX 4AB 11AA
#     *  13   -0.074619  (    6,    0)  1AX 2AB 5AA
#     *  14   -0.074619  (    0,    6)  1AX 2AA 5AB
#     *  15    0.070724  (    3,    1)  1AX 3AB 4AA
#     *  16    0.070724  (    1,    3)  1AX 3AA 4AB
#     *  17    0.056164  (   21,   36)  1AX 8AA 10AB
#     *  18    0.056164  (   36,   21)  1AX 8AB 10AA
#     *  19   -0.048864  (   21,   78)  1AX 8AA 14AB
#     *  20   -0.048864  (   78,   21)  1AX 8AB 14AA
#
#
#    ==> FCI root 4 information <==
#
#     FCI Root 4 energy =    -7.784599355065225
#
#    The 20 most important determinants:
#
#     *   1    0.595809  (   10,    0)  1AX 2AB 6AA
#     *   2    0.595809  (    0,   10)  1AX 2AA 6AB
#     *   3    0.310923  (   15,    0)  1AX 2AB 7AA
#     *   4    0.310923  (    0,   15)  1AX 2AA 7AB
#     *   5    0.177455  (   10,   10)  1AX 6AX
#     *   6   -0.083792  (   10,   45)  1AX 6AA 11AB
#     *   7   -0.083792  (   45,   10)  1AX 6AB 11AA
#     *   8    0.067994  (   10,   78)  1AX 6AA 14AB
#     *   9    0.067994  (   78,   10)  1AX 6AB 14AA
#     *  10   -0.066920  (   10,    1)  1AX 3AB 6AA
#     *  11   -0.066920  (    1,   10)  1AX 3AA 6AB
#     *  12   -0.057100  (   10,   36)  1AX 6AA 10AB
#     *  13   -0.057100  (   36,   10)  1AX 6AB 10AA
#     *  14    0.043280  (   15,   10)  1AX 6AB 7AA
#     *  15    0.043280  (   10,   15)  1AX 6AA 7AB
#     *  16    0.043103  (   15,   78)  1AX 7AA 14AB
#     *  17    0.043103  (   78,   15)  1AX 7AB 14AA
#     *  18   -0.040967  (   15,   45)  1AX 7AA 11AB
#     *  19   -0.040967  (   45,   15)  1AX 7AB 11AA
#     *  20   -0.038268  (   15,   36)  1AX 7AA 10AB
#
# 		 "A good bug is a dead bug"
#
# 			 - Starship Troopers
#
# 		 "I didn't write FORTRAN.  That's the problem."
#
# 			 - Edward Valeev
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYY31VALT
# *** at Fri Sep  8 11:48:49 2023
#
#    => Loading Basis Set <=
#
#     Name: 6-311G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    41 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-311g.gbs
#     atoms 2 entry H          line    21 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-311g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.177896291890     7.016003436600
#          H            0.000000000000     0.000000000000     1.238430238723     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      9.53622  C =      9.53622 [cm^-1]
#   Rotational constants: A = ************  B = 285888.78581  C = 285888.78581 [MHz]
#   Nuclear repulsion =    1.120879682543084
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-311G
#     Blend: 6-311G
#     Number of shells: 10
#     Number of basis functions: 16
#     Number of Cartesian functions: 16
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              10
#       Number of primitives:             21
#       Number of atomic orbitals:        16
#       Number of basis functions:        16
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 18632 doubles for integral storage.
#   We computed 1540 shell quartets total.
#   Whereas there are 1540 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 2.6624149565E-02.
#   Reciprocal condition number of the overlap matrix is 7.1156827819E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         16      16
#    -------------------------
#     Total      16      16
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.70979941909844   -7.70980e+00   0.00000e+00
#    @RHF iter   1:    -7.96611428285363   -2.56315e-01   6.82865e-03 DIIS/ADIIS
#    @RHF iter   2:    -7.97873802494696   -1.26237e-02   8.41583e-04 DIIS/ADIIS
#    @RHF iter   3:    -7.97912302795383   -3.85003e-04   2.03359e-04 DIIS/ADIIS
#    @RHF iter   4:    -7.97915869283064   -3.56649e-05   5.61695e-05 DIIS
#    @RHF iter   5:    -7.97916259931976   -3.90649e-06   9.07802e-06 DIIS
#    @RHF iter   6:    -7.97916269258212   -9.32624e-08   7.57864e-07 DIIS
#    @RHF iter   7:    -7.97916269322194   -6.39818e-10   3.49666e-08 DIIS
#    @RHF iter   8:    -7.97916269322265   -7.06102e-13   3.94081e-09 DIIS
#    @RHF iter   9:    -7.97916269322267   -1.86517e-14   5.91186e-10 DIIS
#    @RHF iter  10:    -7.97916269322267    0.00000e+00   5.69347e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.435606     2A     -0.311165
#
#     Virtual:
#
#        3A      0.002251     4A      0.043335     5A      0.043335
#        6A      0.089547     7A      0.120763     8A      0.154093
#        9A      0.154093    10A      0.236947    11A      0.510527
#       12A      0.591091    13A      0.591091    14A      0.738239
#       15A      2.850405    16A      4.001351
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.97916269322267
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.1208796825430838
#     One-Electron Energy =                 -12.7065420205226225
#     Two-Electron Energy =                   3.6064996447568713
#     Total Energy =                         -7.9791626932226674
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -3.5460993            1.3317682           -2.2143311
#  Magnitude           :                                                    2.2143311
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYY31VALT at Fri Sep  8 11:48:49 2023
# Module time:
# 	user time   =       0.07 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       2.11 seconds =       0.04 minutes
# 	system time =       0.62 seconds =       0.01 minutes
# 	total time  =         16 seconds =       0.27 minutes
#
# Scratch directory: /tmp/
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              10
#       Number of SO shells:              10
#       Number of primitives:             21
#       Number of atomic orbitals:        16
#       Number of basis functions:        16
#
#       Number of irreps:                  1
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  16 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 2701 non-zero two-electron integrals.
#         Stored in file 33.
#
#
#          ---------------------------------------------------------
#                           Configuration Interaction
#                             (a 'D E T C I' module)
#
#                  C. David Sherrill, Daniel G. A. Smith, and
#                               Matt L. Leininger
#          ---------------------------------------------------------
#
#
#    ==> Parameters <==
#
#     EX LEVEL       =        4      H0 BLOCKSIZE  =     1000
#     VAL EX LEVEL   =        0      H0 GUESS SIZE =     1000
#     H0COUPLINGSIZE =        0      H0 COUPLING   =       NO
#     MAXITER        =       24      NUM PRINT     =       20
#     NUM ROOTS      =        5      ICORE         =        1
#     PRINT LVL      =        1      FCI           =      YES
#     R CONV         = 1.00e-04      MIXED         =      YES
#     E CONV         = 1.00e-10      MIXED4        =      YES
#     R4S            =       NO      REPL OTF      =       NO
#     DIAG METHOD    =      SEM      FOLLOW ROOT   =        0
#     PRECONDITIONER = DAVIDSON      UPDATE        = DAVIDSON
#     S              =   0.0000      Ms0           =      YES
#     GUESS VECTOR   =  H0BLOCK      OPENTYPE      =     NONE
#     COLLAPSE SIZE  =        1      HD AVG        = EVANGELISTI
#     MAX NUM VECS   =      125      REF SYM       =     AUTO
#     IOPEN        =       NO
#
#     EX ALLOW       =  1  1  1  1
#     STATE AVERAGE  =  0(1.00)
#
#    ==> CI Orbital and Space information <==
#
#    ------------------------------------
#                Space    Total     A
#    ------------------------------------
#                  Nso       16    16
#                  Nmo       16    16
#                Ndocc        2     2
#                Nsocc        0     0
#    ------------------------------------
#               CI Spaces
#    ------------------------------------
#         Dropped DOCC        0     0
#               Active       16    16
#         Dropped UOCC        0     0
#    ------------------------------------
#
#    ==> Setting up CI strings <==
#
#     There are 120 alpha and 120 beta strings
#     The CI space requires 14400 (1.44E+04) determinants and 1 blocks
#
#    ==> Transforming CI integrals <==
#
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
#
#    ==> Starting CI iterations <==
#
#     H0 Block Eigenvalue =  -7.99571640
#
#     Simultaneous Expansion Method (Block Davidson Method)
#     Using 5 initial trial vectors
#
# (sem_iter): H0block_->H0b_diag[1][1] - H0block_->H0b_diag[2][1] = 0.615031 - -0.615031 = 1.230063 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[3][3] - H0block_->H0b_diag[5][3] = -0.024829 - 0.024829 = -0.049658 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[3][4] - H0block_->H0b_diag[5][4] = 0.579852 - -0.579852 = 1.159704 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[1][7] - H0block_->H0b_diag[2][7] = -0.106538 - 0.106538 = -0.213076 > 1.0E-8
#      Iter   Root       Total Energy       Delta E      C RMS
#
#    @CI  0:     0     -7.995716404953   -9.1166E+00   3.9893E-01
#    @CI  0:     1     -7.872072851606   -8.9930E+00   3.8777E-01
#    @CI  0:     2     -7.834683977061   -8.9556E+00   3.8718E-01
#    @CI  0:     3     -7.834683977060   -8.9556E+00   3.8718E-01
#    @CI  0:     4     -7.770539929334   -8.8914E+00   3.8819E-01
#
#    @CI  1:     0     -8.013233383734   -1.7517E-02   2.5765E-02
#    @CI  1:     1     -7.887545651455   -1.5473E-02   2.0694E-02
#    @CI  1:     2     -7.850166554495   -1.5483E-02   2.0321E-02
#    @CI  1:     3     -7.850166554494   -1.5483E-02   2.0321E-02
#    @CI  1:     4     -7.786048873600   -1.5509E-02   2.0982E-02
#
#    @CI  2:     0     -8.013352081243   -1.1870E-04   4.1687E-03
#    @CI  2:     1     -7.887623198200   -7.7547E-05   3.3977E-03
#    @CI  2:     2     -7.850247728590   -8.1174E-05   4.0175E-03
#    @CI  2:     3     -7.850247728590   -8.1174E-05   4.0175E-03
#    @CI  2:     4     -7.786128865436   -7.9992E-05   3.4288E-03
#
#    @CI  3:     0     -8.013355188160   -3.1069E-06   6.2046E-04
#    @CI  3:     1     -7.887626495066   -3.2969E-06   1.1103E-03
#    @CI  3:     2     -7.850257554795   -9.8262E-06   2.9276E-03
#    @CI  3:     3     -7.850257554794   -9.8262E-06   2.9276E-03
#    @CI  3:     4     -7.786131323836   -2.4584E-06   7.0780E-04
#
#    @CI  4:     0     -8.013355281743   -9.3583E-08   1.7483E-04
#    @CI  4:     1     -7.887627091536   -5.9647E-07   6.8188E-04
#    @CI  4:     2     -7.850261025966   -3.4712E-06   1.3617E-03
#    @CI  4:     3     -7.850261025965   -3.4712E-06   1.3617E-03
#    @CI  4:     4     -7.786131476607   -1.5277E-07   3.2670E-04
#
#    @CI  5:     0     -8.013355288951   -7.2079E-09   3.7443E-05
#    @CI  5:     1     -7.887627232807   -1.4127E-07   1.8810E-04
#    @CI  5:     2     -7.850261464152   -4.3819E-07   2.8066E-04
#    @CI  5:     3     -7.850261464151   -4.3819E-07   2.8066E-04
#    @CI  5:     4     -7.786131524939   -4.8333E-08   1.5817E-04
#
#    @CI  6:     0     -8.013355289284   -3.3287E-10   9.6854E-06
#    @CI  6:     1     -7.887627241263   -8.4562E-09   5.2765E-05
#    @CI  6:     2     -7.850261482074   -1.7923E-08   7.0900E-05
#    @CI  6:     3     -7.850261482074   -1.7923E-08   7.0900E-05
#    @CI  6:     4     -7.786131535914   -1.0974E-08   8.6856E-05
#
#    @CI  7:     0     -8.013355289307   -2.3480E-11   2.4571E-06 c
#    @CI  7:     1     -7.887627242022   -7.5832E-10   1.4919E-05
#    @CI  7:     2     -7.850261483336   -1.2619E-09   1.8776E-05
#    @CI  7:     3     -7.850261483336   -1.2619E-09   1.8776E-05
#    @CI  7:     4     -7.786131538882   -2.9677E-09   4.2498E-05
#
#    @CI  8:     0     -8.013355289308   -7.0877E-13   1.7017E-06 c
#    @CI  8:     1     -7.887627242073   -5.1241E-11   3.5043E-06 c
#    @CI  8:     2     -7.850261483411   -7.4714E-11   4.5098E-06 c
#    @CI  8:     3     -7.850261483410   -7.4722E-11   4.5098E-06 c
#    @CI  8:     4     -7.786131539497   -6.1535E-10   1.8861E-05
#
#    @CI  9:     0     -8.013355289308   -3.2685E-13   1.5578E-06 c
#    @CI  9:     1     -7.887627242075   -2.0322E-12   2.3647E-06 c
#    @CI  9:     2     -7.850261483411   -7.1054E-15   4.5098E-06 c
#    @CI  9:     3     -7.850261483410   -8.8818E-15   4.5098E-06 c
#    @CI  9:     4     -7.786131539627   -1.3046E-10   7.9196E-06
#
#    @CI 10:     0     -8.013355289309   -4.0856E-14   1.5102E-06 c
#    @CI 10:     1     -7.887627242075   1.7764E-15   2.3494E-06 c
#    @CI 10:     2     -7.850261483411   0.0000E+00   4.5098E-06 c
#    @CI 10:     3     -7.850261483410   -8.8818E-15   4.5098E-06 c
#    @CI 10:     4     -7.786131539643   -1.5680E-11   2.3779E-06 c
#
#
#    ==> Energetics <==
#
#     SCF energy =           -7.979162693222667
#     Total CI energy =      -8.013355289308519
#
#    ==> FCI root 0 information <==
#
#     FCI Root 0 energy =    -8.013355289308519
#
#    The 20 most important determinants:
#
#     *   1   -0.987661  (    0,    0)  1AX 2AX
#     *   2    0.043764  (   45,   45)  1AX 11AX
#     *   3    0.041048  (   78,   78)  1AX 14AX
#     *   4    0.038247  (   36,   36)  1AX 10AX
#     *   5   -0.034891  (   36,   78)  1AX 10AA 14AB
#     *   6   -0.034891  (   78,   36)  1AX 10AB 14AA
#     *   7    0.031595  (  106,  106)  2AX 16AX
#     *   8    0.030754  (   10,   10)  1AX 6AX
#     *   9   -0.030380  (   10,   45)  1AX 6AA 11AB
#     *  10   -0.030380  (   45,   10)  1AX 6AB 11AA
#     *  11   -0.029298  (    1,    0)  1AX 2AB 3AA
#     *  12   -0.029298  (    0,    1)  1AX 2AA 3AB
#     *  13    0.025026  (   10,   78)  1AX 6AA 14AB
#     *  14    0.025026  (   78,   10)  1AX 6AB 14AA
#     *  15   -0.023175  (    1,   78)  1AX 3AA 14AB
#     *  16   -0.023175  (   78,    1)  1AX 3AB 14AA
#     *  17    0.023001  (    1,   36)  1AX 3AA 10AB
#     *  18    0.023001  (   36,    1)  1AX 3AB 10AA
#     *  19   -0.022506  (    1,   10)  1AX 3AA 6AB
#     *  20   -0.022506  (   10,    1)  1AX 3AB 6AA
#
#
#    ==> FCI root 1 information <==
#
#     FCI Root 1 energy =    -7.887627242074906
#
#    The 20 most important determinants:
#
#     *   1   -0.626280  (    0,    1)  1AX 2AA 3AB
#     *   2   -0.626280  (    1,    0)  1AX 2AB 3AA
#     *   3   -0.223193  (    0,   15)  1AX 2AA 7AB
#     *   4   -0.223193  (   15,    0)  1AX 2AB 7AA
#     *   5    0.137331  (    1,    1)  1AX 3AX
#     *   6   -0.096391  (   10,    1)  1AX 3AB 6AA
#     *   7   -0.096391  (    1,   10)  1AX 3AA 6AB
#     *   8    0.089160  (   36,    1)  1AX 3AB 10AA
#     *   9    0.089160  (    1,   36)  1AX 3AA 10AB
#     *  10   -0.083956  (   78,    1)  1AX 3AB 14AA
#     *  11   -0.083956  (    1,   78)  1AX 3AA 14AB
#     *  12    0.074430  (    0,   10)  1AX 2AA 6AB
#     *  13    0.074430  (   10,    0)  1AX 2AB 6AA
#     *  14    0.072408  (   45,    1)  1AX 3AB 11AA
#     *  15    0.072408  (    1,   45)  1AX 3AA 11AB
#     *  16    0.064373  (    0,    0)  1AX 2AX
#     *  17   -0.051696  (    0,   36)  1AX 2AA 10AB
#     *  18   -0.051696  (   36,    0)  1AX 2AB 10AA
#     *  19    0.034992  (   36,   15)  1AX 7AB 10AA
#     *  20    0.034992  (   15,   36)  1AX 7AA 10AB
#
#
#    ==> FCI root 2 information <==
#
#     FCI Root 2 energy =    -7.850261483410840
#
#    The 20 most important determinants:
#
#     *   1    0.545984  (    0,    3)  1AX 2AA 4AB
#     *   2    0.545984  (    3,    0)  1AX 2AB 4AA
#     *   3   -0.302180  (    0,   21)  1AX 2AA 8AB
#     *   4   -0.302180  (   21,    0)  1AX 2AB 8AA
#     *   5   -0.250928  (    6,    0)  1AX 2AB 5AA
#     *   6   -0.250928  (    0,    6)  1AX 2AA 5AB
#     *   7    0.083350  (   10,    3)  1AX 4AB 6AA
#     *   8    0.083350  (    3,   10)  1AX 4AA 6AB
#     *   9    0.076521  (   78,    3)  1AX 4AB 14AA
#     *  10    0.076521  (    3,   78)  1AX 4AA 14AB
#     *  11   -0.076518  (   36,    3)  1AX 4AB 10AA
#     *  12   -0.076518  (    3,   36)  1AX 4AA 10AB
#     *  13   -0.071046  (   45,    3)  1AX 4AB 11AA
#     *  14   -0.071046  (    3,   45)  1AX 4AA 11AB
#     *  15   -0.065096  (    1,    3)  1AX 3AA 4AB
#     *  16   -0.065096  (    3,    1)  1AX 3AB 4AA
#     *  17    0.056265  (   36,   21)  1AX 8AB 10AA
#     *  18    0.056265  (   21,   36)  1AX 8AA 10AB
#     *  19   -0.049129  (   78,   21)  1AX 8AB 14AA
#     *  20   -0.049129  (   21,   78)  1AX 8AA 14AB
#
#
#    ==> FCI root 3 information <==
#
#     FCI Root 3 energy =    -7.850261483410286
#
#    The 20 most important determinants:
#
#     *   1    0.545984  (    6,    0)  1AX 2AB 5AA
#     *   2    0.545984  (    0,    6)  1AX 2AA 5AB
#     *   3    0.302180  (   28,    0)  1AX 2AB 9AA
#     *   4    0.302180  (    0,   28)  1AX 2AA 9AB
#     *   5    0.250928  (    3,    0)  1AX 2AB 4AA
#     *   6    0.250928  (    0,    3)  1AX 2AA 4AB
#     *   7    0.083350  (    6,   10)  1AX 5AA 6AB
#     *   8    0.083350  (   10,    6)  1AX 5AB 6AA
#     *   9    0.076521  (    6,   78)  1AX 5AA 14AB
#     *  10    0.076521  (   78,    6)  1AX 5AB 14AA
#     *  11   -0.076518  (    6,   36)  1AX 5AA 10AB
#     *  12   -0.076518  (   36,    6)  1AX 5AB 10AA
#     *  13   -0.071046  (    6,   45)  1AX 5AA 11AB
#     *  14   -0.071046  (   45,    6)  1AX 5AB 11AA
#     *  15   -0.065096  (    6,    1)  1AX 3AB 5AA
#     *  16   -0.065096  (    1,    6)  1AX 3AA 5AB
#     *  17   -0.056265  (   28,   36)  1AX 9AA 10AB
#     *  18   -0.056265  (   36,   28)  1AX 9AB 10AA
#     *  19    0.049129  (   28,   78)  1AX 9AA 14AB
#     *  20    0.049129  (   78,   28)  1AX 9AB 14AA
#
#
#    ==> FCI root 4 information <==
#
#     FCI Root 4 energy =    -7.786131539643014
#
#    The 20 most important determinants:
#
#     *   1    0.594089  (    0,   10)  1AX 2AA 6AB
#     *   2    0.594089  (   10,    0)  1AX 2AB 6AA
#     *   3    0.313861  (   15,    0)  1AX 2AB 7AA
#     *   4    0.313861  (    0,   15)  1AX 2AA 7AB
#     *   5    0.177646  (   10,   10)  1AX 6AX
#     *   6   -0.083258  (   10,   45)  1AX 6AA 11AB
#     *   7   -0.083258  (   45,   10)  1AX 6AB 11AA
#     *   8    0.068165  (   78,   10)  1AX 6AB 14AA
#     *   9    0.068165  (   10,   78)  1AX 6AA 14AB
#     *  10   -0.067028  (   10,    1)  1AX 3AB 6AA
#     *  11   -0.067028  (    1,   10)  1AX 3AA 6AB
#     *  12   -0.056203  (   36,   10)  1AX 6AB 10AA
#     *  13   -0.056203  (   10,   36)  1AX 6AA 10AB
#     *  14    0.044135  (   15,   10)  1AX 6AB 7AA
#     *  15    0.044135  (   10,   15)  1AX 6AA 7AB
#     *  16    0.043803  (   15,   78)  1AX 7AA 14AB
#     *  17    0.043803  (   78,   15)  1AX 7AB 14AA
#     *  18   -0.041226  (   15,   45)  1AX 7AA 11AB
#     *  19   -0.041226  (   45,   15)  1AX 7AB 11AA
#     *  20   -0.038534  (   15,   36)  1AX 7AA 10AB
#
# 		 "A good bug is a dead bug"
#
# 			 - Starship Troopers
#
# 		 "I didn't write FORTRAN.  That's the problem."
#
# 			 - Edward Valeev
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYY31VALT
# *** at Fri Sep  8 11:48:50 2023
#
#    => Loading Basis Set <=
#
#     Name: 6-311G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    41 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-311g.gbs
#     atoms 2 entry H          line    21 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-311g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          LI           0.000000000000     0.000000000000    -0.179946969606     7.016003436600
#          H            0.000000000000     0.000000000000     1.252706091619     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A = ************  B =      9.32011  C =      9.32011 [cm^-1]
#   Rotational constants: A = ************  B = 279409.93020  C = 279409.93020 [MHz]
#   Nuclear repulsion =    1.108106124907265
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-311G
#     Blend: 6-311G
#     Number of shells: 10
#     Number of basis functions: 16
#     Number of Cartesian functions: 16
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              10
#       Number of primitives:             21
#       Number of atomic orbitals:        16
#       Number of basis functions:        16
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 18632 doubles for integral storage.
#   We computed 1540 shell quartets total.
#   Whereas there are 1540 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 2.7502097371E-02.
#   Reciprocal condition number of the overlap matrix is 7.3630193518E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         16      16
#    -------------------------
#     Total      16      16
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:    -7.70925737627995   -7.70926e+00   0.00000e+00
#    @RHF iter   1:    -7.96704754412615   -2.57790e-01   6.80114e-03 DIIS/ADIIS
#    @RHF iter   2:    -7.97972728085847   -1.26797e-02   8.45922e-04 DIIS/ADIIS
#    @RHF iter   3:    -7.98012052458078   -3.93244e-04   2.05930e-04 DIIS/ADIIS
#    @RHF iter   4:    -7.98015744844243   -3.69239e-05   5.69603e-05 DIIS
#    @RHF iter   5:    -7.98016148377283   -4.03533e-06   9.09801e-06 DIIS
#    @RHF iter   6:    -7.98016157729097   -9.35181e-08   7.58425e-07 DIIS
#    @RHF iter   7:    -7.98016157793661   -6.45640e-10   3.47694e-08 DIIS
#    @RHF iter   8:    -7.98016157793734   -7.31859e-13   4.01756e-09 DIIS
#    @RHF iter   9:    -7.98016157793735   -1.06581e-14   5.89314e-10 DIIS
#    @RHF iter  10:    -7.98016157793735    1.77636e-15   5.86199e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -2.436784     2A     -0.310389
#
#     Virtual:
#
#        3A      0.001983     4A      0.043215     5A      0.043215
#        6A      0.089683     7A      0.120342     8A      0.153819
#        9A      0.153819    10A      0.236556    11A      0.510841
#       12A      0.590519    13A      0.590519    14A      0.733990
#       15A      2.848726    16A      3.999380
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.98016157793735
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.1081061249072652
#     One-Electron Energy =                 -12.6821890849331140
#     Two-Electron Energy =                   3.5939213820884977
#     Total Energy =                         -7.9801615779373503
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -3.5747461            1.3471200           -2.2276261
#  Magnitude           :                                                    2.2276261
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYY31VALT at Fri Sep  8 11:48:50 2023
# Module time:
# 	user time   =       0.06 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       2.97 seconds =       0.05 minutes
# 	system time =       0.79 seconds =       0.01 minutes
# 	total time  =         17 seconds =       0.28 minutes
#
# Scratch directory: /tmp/
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
# ...
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @RHF Final Energy:    -7.96108344604602
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.7216052872772727
#     One-Electron Energy =                 -11.8204057394136939
#     Two-Electron Energy =                   3.1377170060903978
#     Total Energy =                         -7.9610834460460236
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -5.0653234            2.0686543           -2.9966691
#  Magnitude           :                                                    2.9966691
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMK4CY657ALT at Tue Sep  5 11:52:51 2023
# Module time:
# 	user time   =       0.07 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      59.24 seconds =       0.99 minutes
# 	system time =       8.35 seconds =       0.14 minutes
# 	total time  =         67 seconds =       1.12 minutes
#
# Scratch directory: /tmp/
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              10
#       Number of SO shells:              10
#       Number of primitives:             21
#       Number of atomic orbitals:        16
#       Number of basis functions:        16
#
#       Number of irreps:                  1
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  16 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 2701 non-zero two-electron integrals.
#         Stored in file 33.
#
#
#          ---------------------------------------------------------
#                           Configuration Interaction
#                             (a 'D E T C I' module)
#
#                  C. David Sherrill, Daniel G. A. Smith, and
#                               Matt L. Leininger
#          ---------------------------------------------------------
#
#
#    ==> Parameters <==
#
#     EX LEVEL       =        4      H0 BLOCKSIZE  =     1000
#     VAL EX LEVEL   =        0      H0 GUESS SIZE =     1000
#     H0COUPLINGSIZE =        0      H0 COUPLING   =       NO
#     MAXITER        =       24      NUM PRINT     =       20
#     NUM ROOTS      =        5      ICORE         =        1
#     PRINT LVL      =        1      FCI           =      YES
#     R CONV         = 1.00e-04      MIXED         =      YES
#     E CONV         = 1.00e-10      MIXED4        =      YES
#     R4S            =       NO      REPL OTF      =       NO
#     DIAG METHOD    =      SEM      FOLLOW ROOT   =        0
#     PRECONDITIONER = DAVIDSON      UPDATE        = DAVIDSON
#     S              =   0.0000      Ms0           =      YES
#     GUESS VECTOR   =  H0BLOCK      OPENTYPE      =     NONE
#     COLLAPSE SIZE  =        1      HD AVG        = EVANGELISTI
#     MAX NUM VECS   =      125      REF SYM       =     AUTO
#     IOPEN        =       NO
#
#     EX ALLOW       =  1  1  1  1
#     STATE AVERAGE  =  0(1.00)
#
#    ==> CI Orbital and Space information <==
#
#    ------------------------------------
#                Space    Total     A
#    ------------------------------------
#                  Nso       16    16
#                  Nmo       16    16
#                Ndocc        2     2
#                Nsocc        0     0
#    ------------------------------------
#               CI Spaces
#    ------------------------------------
#         Dropped DOCC        0     0
#               Active       16    16
#         Dropped UOCC        0     0
#    ------------------------------------
#
#    ==> Setting up CI strings <==
#
#     There are 120 alpha and 120 beta strings
#     The CI space requires 14400 (1.44E+04) determinants and 1 blocks
#
#    ==> Transforming CI integrals <==
#
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
#
#    ==> Starting CI iterations <==
#
#     H0 Block Eigenvalue =  -7.98519002
#
#     Simultaneous Expansion Method (Block Davidson Method)
#     Using 5 initial trial vectors
#
# (sem_iter): H0block_->H0b_diag[1][1] - H0block_->H0b_diag[2][1] = 0.610541 - -0.610541 = 1.221083 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[3][3] - H0block_->H0b_diag[5][3] = 0.353694 - -0.353694 = 0.707389 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[3][4] - H0block_->H0b_diag[5][4] = 0.487607 - -0.487607 = 0.975214 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[1][7] - H0block_->H0b_diag[2][7] = -0.207286 - 0.207286 = -0.414571 > 1.0E-8
# (sem_iter): H0block_->H0b_diag[1][8] - H0block_->H0b_diag[2][8] = 0.144349 - -0.144349 = 0.288697 > 1.0E-8
#      Iter   Root       Total Energy       Delta E      C RMS
#
#    @CI  0:     0     -7.985190019117   -8.7068E+00   3.9054E-01
#    @CI  0:     1     -7.897575794784   -8.6192E+00   3.8680E-01
#    @CI  0:     2     -7.861975673400   -8.5836E+00   3.8476E-01
#    @CI  0:     3     -7.861975673400   -8.5836E+00   3.8476E-01
#    @CI  0:     4     -7.784518142268   -8.5061E+00   3.8551E-01
#
#    @CI  1:     0     -8.001157265317   -1.5967E-02   2.2359E-02
#    @CI  1:     1     -7.912873213874   -1.5297E-02   1.9337E-02
#    @CI  1:     2     -7.876860942569   -1.4885E-02   1.7687E-02
#    @CI  1:     3     -7.876860942568   -1.4885E-02   1.7687E-02
#    @CI  1:     4     -7.799578855611   -1.5061E-02   1.8767E-02
#
#    @CI  2:     0     -8.001251291540   -9.4026E-05   3.8057E-03
#    @CI  2:     1     -7.912943616990   -7.0403E-05   3.2735E-03
#    @CI  2:     2     -7.876918484150   -5.7542E-05   2.6416E-03
#    @CI  2:     3     -7.876918484150   -5.7542E-05   2.6416E-03
#    @CI  2:     4     -7.799645910353   -6.7055E-05   3.1744E-03
#
#    @CI  3:     0     -8.001255057677   -3.7661E-06   9.6249E-04
#    @CI  3:     1     -7.912946945577   -3.3286E-06   1.4603E-03
#    @CI  3:     2     -7.876920236685   -1.7525E-06   5.7614E-04
#    @CI  3:     3     -7.876920236685   -1.7525E-06   5.7614E-04
#    @CI  3:     4     -7.799648994062   -3.0837E-06   1.2974E-03
#
#    @CI  4:     0     -8.001255334420   -2.7674E-07   2.8349E-04
#    @CI  4:     1     -7.912947968092   -1.0225E-06   7.8984E-04
#    @CI  4:     2     -7.876920374468   -1.3778E-07   3.1063E-04
#    @CI  4:     3     -7.876920374468   -1.3778E-07   3.1063E-04
#    @CI  4:     4     -7.799651099792   -2.1057E-06   1.7918E-03
#
#    @CI  5:     0     -8.001255353032   -1.8611E-08   5.8491E-05
#    @CI  5:     1     -7.912948115198   -1.4711E-07   1.6811E-04
#    @CI  5:     2     -7.876920429045   -5.4577E-08   1.6115E-04
#    @CI  5:     3     -7.876920429045   -5.4577E-08   1.6115E-04
#    @CI  5:     4     -7.799652614131   -1.5143E-06   8.9281E-04
#
#    @CI  6:     0     -8.001255353817   -7.8530E-10   1.4628E-05
#    @CI  6:     1     -7.912948122036   -6.8384E-09   4.5219E-05
#    @CI  6:     2     -7.876920437262   -8.2169E-09   5.6157E-05
#    @CI  6:     3     -7.876920437262   -8.2169E-09   5.6157E-05
#    @CI  6:     4     -7.799653126545   -5.1241E-07   8.8413E-04
#
#    @CI  7:     0     -8.001255353862   -4.4924E-11   3.0762E-06 c
#    @CI  7:     1     -7.912948122525   -4.8825E-10   1.0519E-05
#    @CI  7:     2     -7.876920438260   -9.9738E-10   1.7428E-05
#    @CI  7:     3     -7.876920438259   -9.9738E-10   1.7428E-05
#    @CI  7:     4     -7.799653965686   -8.3914E-07   1.1154E-03
#
#    @CI  8:     0     -8.001255353862   -5.2580E-13   2.3727E-06 c
#    @CI  8:     1     -7.912948122546   -2.1432E-11   2.0570E-06 c
#    @CI  8:     2     -7.876920438335   -7.5197E-11   4.1325E-06 c
#    @CI  8:     3     -7.876920438335   -7.5218E-11   4.1325E-06 c
#    @CI  8:     4     -7.799654310015   -3.4433E-07   3.5765E-04
#
#    @CI  9:     0     -8.001255353862   -2.6645E-14   2.3520E-06 c
#    @CI  9:     1     -7.912948122546   -2.6290E-13   1.8514E-06 c
#    @CI  9:     2     -7.876920438335   -5.3291E-15   4.1325E-06 c
#    @CI  9:     3     -7.876920438335   1.4211E-14   4.1325E-06 c
#    @CI  9:     4     -7.799654337160   -2.7145E-08   7.6296E-05
#
#    @CI 10:     0     -8.001255353862   -1.2434E-14   2.3646E-06 c
#    @CI 10:     1     -7.912948122546   -3.5527E-15   1.8464E-06 c
#    @CI 10:     2     -7.876920438335   5.3291E-15   4.1325E-06 c
#    @CI 10:     3     -7.876920438335   0.0000E+00   4.1325E-06 c
#    @CI 10:     4     -7.799654338706   -1.5459E-09   2.2316E-05
#
#    @CI 11:     0     -8.001255353862   -4.4409E-14   2.3469E-06 c
#    @CI 11:     1     -7.912948122546   -2.6645E-14   1.8852E-06 c
#    @CI 11:     2     -7.876920438335   3.5527E-15   4.1325E-06 c
#    @CI 11:     3     -7.876920438335   0.0000E+00   4.1325E-06 c
#    @CI 11:     4     -7.799654338843   -1.3677E-10   7.0061E-06
#
#    @CI 12:     0     -8.001255353862   -1.7764E-15   2.3357E-06 c
#    @CI 12:     1     -7.912948122546   -5.6843E-14   1.7970E-06 c
#    @CI 12:     2     -7.876920438335   -1.0658E-14   4.1325E-06 c
#    @CI 12:     3     -7.876920438335   -5.3291E-15   4.1325E-06 c
#    @CI 12:     4     -7.799654338854   -1.1919E-11   1.8985E-06 c
#
#
#    ==> Energetics <==
#
#     SCF energy =           -7.961083446046024
#     Total CI energy =      -8.001255353862375
#
#    ==> FCI root 0 information <==
#
#     FCI Root 0 energy =    -8.001255353862375
#
#    The 20 most important determinants:
#
#     *   1   -0.971795  (    0,    0)  1AX 2AX
#     *   2    0.076840  (   36,   36)  1AX 10AX
#     *   3   -0.063685  (    0,    1)  1AX 2AA 3AB
#     *   4   -0.063685  (    1,    0)  1AX 2AB 3AA
#     *   5    0.060584  (   78,   78)  1AX 14AX
#     *   6    0.048525  (   10,   10)  1AX 6AX
#     *   7    0.048270  (   36,    1)  1AX 3AB 10AA
#     *   8    0.048270  (    1,   36)  1AX 3AA 10AB
#     *   9    0.047871  (   78,   10)  1AX 6AB 14AA
#     *  10    0.047871  (   10,   78)  1AX 6AA 14AB
#     *  11    0.046205  (   10,    1)  1AX 3AB 6AA
#     *  12    0.046205  (    1,   10)  1AX 3AA 6AB
#     *  13    0.044204  (    1,    1)  1AX 3AX
#     *  14    0.043831  (   78,    1)  1AX 3AB 14AA
#     *  15    0.043831  (    1,   78)  1AX 3AA 14AB
#     *  16    0.043675  (   36,   10)  1AX 6AB 10AA
#     *  17    0.043675  (   10,   36)  1AX 6AA 10AB
#     *  18    0.040385  (   36,   78)  1AX 10AA 14AB
#     *  19    0.040385  (   78,   36)  1AX 10AB 14AA
#     *  20    0.031781  (  106,  106)  2AX 16AX
#
#
#    ==> FCI root 1 information <==
#
#     FCI Root 1 energy =    -7.912948122546368
#
#    The 20 most important determinants:
#
#     *   1   -0.625844  (    1,    0)  1AX 2AB 3AA
#     *   2   -0.625844  (    0,    1)  1AX 2AA 3AB
#     *   3    0.191283  (    1,    1)  1AX 3AX
#     *   4   -0.135257  (   15,    0)  1AX 2AB 7AA
#     *   5   -0.135257  (    0,   15)  1AX 2AA 7AB
#     *   6    0.132554  (    0,    0)  1AX 2AX
#     *   7    0.132546  (    1,   10)  1AX 3AA 6AB
#     *   8    0.132546  (   10,    1)  1AX 3AB 6AA
#     *   9    0.115071  (    1,   78)  1AX 3AA 14AB
#     *  10    0.115071  (   78,    1)  1AX 3AB 14AA
#     *  11   -0.112916  (   10,    0)  1AX 2AB 6AA
#     *  12   -0.112916  (    0,   10)  1AX 2AA 6AB
#     *  13    0.102409  (    1,   36)  1AX 3AA 10AB
#     *  14    0.102409  (   36,    1)  1AX 3AB 10AA
#     *  15    0.035892  (   10,   10)  1AX 6AX
#     *  16    0.033743  (   15,   78)  1AX 7AA 14AB
#     *  17    0.033743  (   78,   15)  1AX 7AB 14AA
#     *  18   -0.033275  (   78,   78)  1AX 14AX
#     *  19    0.029558  (   15,   36)  1AX 7AA 10AB
#     *  20    0.029558  (   36,   15)  1AX 7AB 10AA
#
#
#    ==> FCI root 2 information <==
#
#     FCI Root 2 energy =    -7.876920438334817
#
#    The 20 most important determinants:
#
#     *   1    0.483013  (    0,    3)  1AX 2AA 4AB
#     *   2    0.483013  (    3,    0)  1AX 2AB 4AA
#     *   3    0.359580  (    0,    6)  1AX 2AA 5AB
#     *   4    0.359580  (    6,    0)  1AX 2AB 5AA
#     *   5    0.214034  (    0,   28)  1AX 2AA 9AB
#     *   6    0.214034  (   28,    0)  1AX 2AB 9AA
#     *   7    0.153855  (    0,   21)  1AX 2AA 8AB
#     *   8    0.153855  (   21,    0)  1AX 2AB 8AA
#     *   9   -0.098571  (   78,    3)  1AX 4AB 14AA
#     *  10   -0.098571  (    3,   78)  1AX 4AA 14AB
#     *  11   -0.094811  (   10,    3)  1AX 4AB 6AA
#     *  12   -0.094811  (    3,   10)  1AX 4AA 6AB
#     *  13   -0.085623  (   36,    3)  1AX 4AB 10AA
#     *  14   -0.085623  (    3,   36)  1AX 4AA 10AB
#     *  15   -0.078932  (    1,    3)  1AX 3AA 4AB
#     *  16   -0.078932  (    3,    1)  1AX 3AB 4AA
#     *  17   -0.073381  (   78,    6)  1AX 5AB 14AA
#     *  18   -0.073381  (    6,   78)  1AX 5AA 14AB
#     *  19   -0.070582  (   10,    6)  1AX 5AB 6AA
#     *  20   -0.070582  (    6,   10)  1AX 5AA 6AB
#
#
#    ==> FCI root 3 information <==
#
#     FCI Root 3 energy =    -7.876920438334542
#
#    The 20 most important determinants:
#
#     *   1   -0.483013  (    6,    0)  1AX 2AB 5AA
#     *   2   -0.483013  (    0,    6)  1AX 2AA 5AB
#     *   3    0.359580  (    3,    0)  1AX 2AB 4AA
#     *   4    0.359580  (    0,    3)  1AX 2AA 4AB
#     *   5    0.214034  (   21,    0)  1AX 2AB 8AA
#     *   6    0.214034  (    0,   21)  1AX 2AA 8AB
#     *   7   -0.153855  (   28,    0)  1AX 2AB 9AA
#     *   8   -0.153855  (    0,   28)  1AX 2AA 9AB
#     *   9    0.098571  (    6,   78)  1AX 5AA 14AB
#     *  10    0.098571  (   78,    6)  1AX 5AB 14AA
#     *  11    0.094811  (    6,   10)  1AX 5AA 6AB
#     *  12    0.094811  (   10,    6)  1AX 5AB 6AA
#     *  13    0.085623  (    6,   36)  1AX 5AA 10AB
#     *  14    0.085623  (   36,    6)  1AX 5AB 10AA
#     *  15    0.078932  (    6,    1)  1AX 3AB 5AA
#     *  16    0.078932  (    1,    6)  1AX 3AA 5AB
#     *  17   -0.073381  (    3,   78)  1AX 4AA 14AB
#     *  18   -0.073381  (   78,    3)  1AX 4AB 14AA
#     *  19   -0.070582  (    3,   10)  1AX 4AA 6AB
#     *  20   -0.070582  (   10,    3)  1AX 4AB 6AA
#
#
#    ==> FCI root 4 information <==
#
#     FCI Root 4 energy =    -7.799654338854447
#
#    The 20 most important determinants:
#
#     *   1   -0.619194  (   15,    0)  1AX 2AB 7AA
#     *   2   -0.619194  (    0,   15)  1AX 2AA 7AB
#     *   3    0.186095  (   10,    0)  1AX 2AB 6AA
#     *   4    0.186095  (    0,   10)  1AX 2AA 6AB
#     *   5    0.129181  (   15,   10)  1AX 6AB 7AA
#     *   6    0.129181  (   10,   15)  1AX 6AA 7AB
#     *   7    0.120772  (   15,   78)  1AX 7AA 14AB
#     *   8    0.120772  (   78,   15)  1AX 7AB 14AA
#     *   9   -0.103315  (   36,    0)  1AX 2AB 10AA
#     *  10   -0.103315  (    0,   36)  1AX 2AA 10AB
#     *  11    0.099678  (   15,    1)  1AX 3AB 7AA
#     *  12    0.099678  (    1,   15)  1AX 3AA 7AB
#     *  13    0.094991  (    1,    0)  1AX 2AB 3AA
#     *  14    0.094991  (    0,    1)  1AX 2AA 3AB
#     *  15    0.086433  (   15,   36)  1AX 7AA 10AB
#     *  16    0.086433  (   36,   15)  1AX 7AB 10AA
#     *  17   -0.086171  (   15,   15)  1AX 7AX
#     *  18   -0.061908  (   10,   10)  1AX 6AX
#     *  19    0.043139  (   36,   36)  1AX 10AX
#     *  20   -0.039335  (   10,    1)  1AX 3AB 6AA
#
# 		 "A good bug is a dead bug"
#
# 			 - Starship Troopers
#
# 		 "I didn't write FORTRAN.  That's the problem."
#
# 			 - Edward Valeev

# %%
wfn.variable("CI ROOT 0 TOTAL ENERGY")

# %%
# json file name
subdirname = "/Users/jfoley19/Code/data_repository/Mapol/LiH/qed_fci/"

ref_file = "LiH_qed-fci_6-311g_coherent_state_basis_10_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"

dirname = "/Users/jfoley19/Code/data_repository/Mapol/LiH/qed_fci/bond_stretch_50_points/6311g/number_basis/"
fn_np1 = "LiH_6311g_fci_number_basis_np_1_pes.json"
fn_np2 = "LiH_6311g_fci_number_basis_np_2_pes.json"
fn_np3 = "LiH_6311g_fci_number_basis_np_3_pes.json"
fn_np4 = "LiH_6311g_fci_number_basis_np_4_pes.json"
fn_np5 = "LiH_6311g_fci_number_basis_np_5_pes.json"
fn_np6 = "LiH_6311g_fci_number_basis_np_6_pes.json"
fn_np7 = "LiH_6311g_fci_number_basis_np_7_pes.json"
fn_np8 = "LiH_6311g_fci_number_basis_np_8_pes.json"
fn_np9 = "LiH_6311g_fci_number_basis_np_9_pes.json"
fn_np10 = "LiH_6311g_fci_number_basis_np_10_pes.json"

csdirname = "/Users/jfoley19/Code/data_repository/Mapol/LiH/qed_fci/bond_stretch_50_points/6311g/coherent_state_basis/"
cs_np1 = "LiH_qed-fci_6-311g_coherent_state_basis_1_lambda_0.0_0.0_0.05_omega_0.12086.json"
cs_np2 = "LiH_qed-fci_6-311g_coherent_state_basis_2_lambda_0.0_0.0_0.05_omega_0.12086.json"
cs_np3 = "LiH_qed-fci_6-311g_coherent_state_basis_3_lambda_0.0_0.0_0.05_omega_0.12086.json"
cs_np4 = "LiH_qed-fci_6-311g_coherent_state_basis_4_lambda_0.0_0.0_0.05_omega_0.12086.json"
cs_np5 = "LiH_qed-fci_6-311g_coherent_state_basis_5_lambda_0.0_0.0_0.05_omega_0.12086.json"
cs_np6 = "LiH_qed-fci_6-311g_coherent_state_basis_6_lambda_0.0_0.0_0.05_omega_0.12086.json"
cs_np7 = "LiH_qed-fci_6-311g_coherent_state_basis_7_lambda_0.0_0.0_0.05_omega_0.12086.json"
cs_np8 = "LiH_qed-fci_6-311g_coherent_state_basis_8_lambda_0.0_0.0_0.05_omega_0.12086.json"


reff1 = open(subdirname + ref_file)
rdata = json.load(reff1)

# %%
# load json file into a dictionary called data
f1 = open(dirname + fn_np1)
f2 = open(dirname + fn_np2)
f3 = open(dirname + fn_np3)
f4 = open(dirname + fn_np4)
f5 = open(dirname + fn_np5)
f6 = open(dirname + fn_np6)
f7 = open(dirname + fn_np7)
f8 = open(dirname + fn_np8)
f9 = open(dirname + fn_np9)
f10 = open(dirname + fn_np10)


csf1 = open(csdirname + cs_np1)
csf2 = open(csdirname + cs_np2)
csf3 = open(csdirname + cs_np3)
csf4 = open(csdirname + cs_np4)
csf5 = open(csdirname + cs_np5)
csf6 = open(csdirname + cs_np6)
csf7 = open(csdirname + cs_np7)
csf8 = open(csdirname + cs_np8)


data1 = json.load(f1)
data2 = json.load(f2)
data3 = json.load(f3)
data4 = json.load(f4)
data5 = json.load(f5)
data6 = json.load(f6)
data7 = json.load(f7)
data8 = json.load(f8)
data9 = json.load(f9)
data10 = json.load(f10)


csdata1 = json.load(csf1)
csdata2 = json.load(csf2)
csdata3 = json.load(csf3)
csdata4 = json.load(csf4)
csdata5 = json.load(csf5)
csdata6 = json.load(csf6)
csdata7 = json.load(csf7)
csdata8 = json.load(csf8)

# %%
E_data1 = np.array(data1["return_result"])
E_data2 = np.array(data2["return_result"])
E_data3 = np.array(data3["return_result"])
E_data4 = np.array(data4["return_result"])
E_data5 = np.array(data5["return_result"])
E_data6 = np.array(data6["return_result"])
E_data7 = np.array(data7["return_result"])
E_data8 = np.array(data8["return_result"])
E_data9 = np.array(data9["return_result"])
E_data10 = np.array(data10["return_result"])

csE_data1 = np.array(csdata1["return_result"])
csE_data2 = np.array(csdata2["return_result"])
csE_data3 = np.array(csdata3["return_result"])
csE_data4 = np.array(csdata4["return_result"])
csE_data5 = np.array(csdata5["return_result"])
csE_data6 = np.array(csdata6["return_result"])
csE_data7 = np.array(csdata7["return_result"])
csE_data8 = np.array(csdata8["return_result"])

ref_data = np.array(rdata["return_result"])
r_data = np.linspace(1.4, 2.2, 50)
omega = 0.12086
print(omega)
# Out:
# 0.12086

# %%
def mae(array, reference):
    diff = np.abs(array - reference)
    mae = np.mean(diff)
    return mae

# %%
numph = np.linspace(1, 8, 8, dtype=int)
cs_mae = np.zeros(8)
np_mae = np.zeros(8)

cs_mae[0] = mae(csE_data1[:,0], E_data10[:,0])
cs_mae[1] = mae(csE_data2[:,0], E_data10[:,0])
cs_mae[2] = mae(csE_data3[:,0], E_data10[:,0])
cs_mae[3] = mae(csE_data4[:,0], E_data10[:,0])
cs_mae[4] = mae(csE_data5[:,0], E_data10[:,0])
cs_mae[5] = mae(csE_data6[:,0], E_data10[:,0])
cs_mae[6] = mae(csE_data7[:,0], E_data10[:,0])
cs_mae[7] = mae(csE_data8[:,0], E_data10[:,0])

np_mae[0] = mae(E_data1[:,0], E_data10[:,0])
np_mae[1] = mae(E_data2[:,0], E_data10[:,0])
np_mae[2] = mae(E_data3[:,0], E_data10[:,0])
np_mae[3] = mae(E_data4[:,0], E_data10[:,0])
np_mae[4] = mae(E_data5[:,0], E_data10[:,0])
np_mae[5] = mae(E_data6[:,0], E_data10[:,0])
np_mae[6] = mae(E_data7[:,0], E_data10[:,0])
np_mae[7] = mae(E_data8[:,0], E_data10[:,0])

print(-7.801713122264944--7.801713122507062)
# Out:
# 2.4211743721025414e-10

# %%
from matplotlib import cm
from matplotlib import rcParams

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

plt.plot(numph[:6], np_mae[:6], "r-o", label="Photon Number Basis")
plt.plot(numph[:6], cs_mae[:6], "b-o", label="Coherent State Basis")
plt.yscale("log")
plt.ylim(0.5e-10, 1e-3)
plt.xlabel("Number of photon states")
plt.ylabel("Mean Absolute Error (Hartrees)")
plt.legend()
plt.tight_layout()
plt.savefig("LiH_error_vs_np.eps", dpi=150)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# get the minimum value of the ground-state energy along the CO stretch coordinate
E_min = np.min(E_data[:,0])

print(np.allclose(E_data1[:,2],E_data10[:,2] ))
print(np.allclose(E_data2[:,2],E_data10[:,2] ))
print(np.allclose(E_data3[:,2],E_data10[:,2] ))

# %%
plt.plot(r_data, fci_e0, 'black', linestyle="dashed", label="Cavity Free")
plt.plot(r_data, csE_data1[:,0], 'b-o', label="Minimal Coherent State Basis")
plt.plot(r_data, E_data1[:,0], 'r-o', label="Minimal Photon Number Basis")
plt.plot(r_data, csE_data6[:,0], 'black', marker="s", ms="6", mfc='none', label="Converged Ground state")
plt.ylabel("Ground-state Energy (Hartrees)")
plt.xlabel("Bond length (Angstroms)")
plt.legend()
plt.tight_layout()
plt.savefig("LiH_ground_surface.png", dpi=150)
plt.show()

# %%
# there is a crossing between the UP state and 5th excited state for the NP=1 data in the CS basis at geometry 43
cs_np1_up = np.copy(csE_data1[:,3])
cs_np1_up[43:] = np.copy(csE_data1[43:,5])

# %%
# there is a crossing between the UP state and 5th excited state for the NP=1 data in the CS basis at geometry 43
pn_np1_up = np.copy(E_data1[:,3])
pn_np1_up[25:35] = np.copy(E_data1[25:35,5])
pn_np1_up[35:] = np.copy(E_data1[35:,7])

# %%
# find the minimum of the cavity-free ground-state
E_min = np.min(np.array(fci_e0))
print(E_min)
# Out:
# -8.019650240590536

# %%
plt.plot(r_data, (np.array(fci_e0)+omega-E_min) * 27.2114, 'black', linestyle="dashed")
plt.plot(r_data, (np.array(fci_e1)-E_min) * 27.2114, 'black', linestyle="dashed", label="Cavity Free")
plt.plot(r_data, (ref_data[:,1]-E_min) * 27.2114, 'blue', marker="o")
plt.plot(r_data, (ref_data[:,2]-E_min) * 27.2114, 'blue', marker="o", label="Converged Polariton States")
plt.plot(r_data, (E_data1[:,1]-E_min) * 27.2114, 'r-o')
#plt.plot(r_data, (E_data1[:,2]-E_min) * 27.2114, 'g-o')
#plt.plot(r_data, (E_data1[:,5]-E_min) * 27.2114, 'r-o')
#plt.plot(r_data, (E_data1[:,7]-E_min) * 27.2114, 'g-o')
plt.plot(r_data, (pn_np1_up-E_min) * 27.2114, 'r-o', label="Minimal Coherent State Basis")
plt.ylabel("Polariton Energies (eV)")
plt.xlabel("Bond length (Angstroms)")
plt.ylim(2.25, 4.75)
plt.tight_layout() 
plt.legend()
plt.savefig("LiH_polariton_pn.png", dpi=150)
plt.show()

# %% [markdown]
# #plt.plot(r_data, np.array(fci_e0)+omega, label='fci gs + omega')
# #plt.plot(r_data, fci_e1, label='fci es')
# plt.plot(r_data, csE_data1[:,1], label="cs-qed-fci lp")
# plt.plot(r_data, csE_data1[:,3], label="cs-qed-fci up")
# plt.plot(r_data, E_data1[:,1], label='qed-fci lp')
# plt.plot(r_data, E_data1[:,3], label='qed-fci up')
# plt.legend()
# plt.show()

# %%
#plt.plot(r_data, E_data1[:,0], label="Eg Np1")
#plt.plot(r_data, fci_e0, label='fci gs')
plt.plot(r_data, np.array(fci_e0)+omega, label='fci gs + omega')
plt.plot(r_data, fci_e1, label='fci es')
#plt.plot(r_data, E_data2[:,0], label='qed-fci gs')
plt.plot(r_data, E_data4[:,1], label='qed-fci lp')
plt.plot(r_data, E_data4[:,3], label='qed-fci up')
plt.plot(r_data, E_data5[:,1], 'r--', label='qed-fci lp')
plt.plot(r_data, E_data5[:,3], 'r--', label='qed-fci up')


plt.legend()
plt.show()

# %%
# plot some excited-state surfaces
#plt.plot(r_data, E_data[:,0], label="E1")
#plt.plot(r_data, E_data[:,1], label="E2")
#plt.plot(r_data, E_data[:,2], label="E3")
plt.plot(r_data, (E_data[:,3]-E_min)*27.211, label="E4")
plt.plot(r_data, (E_data[:,4]-E_min)*27.211, label="E5")
plt.plot(r_data, (E_data[:,5]-E_min)*27.211, label="E6")
plt.plot(r_data, (E_data[:,6]-E_min)*27.211, label="E7")
plt.plot(r_data, (E_data[:,7]-E_min)*27.211, label="E8")
plt.plot(r_data, (E_data[:,8]-E_min)*27.211, label="E9")
plt.plot(r_data, (E_data[:,9]-E_min)*27.211, label="E10")
plt.plot(r_data, (E_data[:,10]-E_min)*27.211, label="E11")
plt.plot(r_data, (E_data[:,11]-E_min)*27.211, label="E12")
plt.ylabel("Energy relative to $E_{min}$ (eV)")
plt.xlabel("CO Bondlength (Angstroms)")
plt.legend()
plt.show()

# %%
# plot the absolute value of the z-component of mu_1j 
# this gives us some hint about how to continue surfaces
plt.plot(r_data, np.abs(Mu_data[:,0,1,2]), label="mu12")
plt.plot(r_data, np.abs(Mu_data[:,0,2,2]), label="mu13")
plt.plot(r_data, np.abs(Mu_data[:,0,3,2]), label="mu14")
plt.plot(r_data, np.abs(Mu_data[:,0,4,2]), label="mu15")
plt.plot(r_data, np.abs(Mu_data[:,0,5,2]), label="mu16")
plt.plot(r_data, np.abs(Mu_data[:,0,6,2]), label="mu17")
plt.legend()
plt.show()
