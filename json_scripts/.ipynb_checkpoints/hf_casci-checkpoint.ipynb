# %%
import numpy as np
import psi4
psi4.core.set_output_file("hf.out")

# %%
mol_str = """
H
F 1 0.6
symmetry c2v
"""
mol_tmpl = """
H
F 1 **R**
symmetry c2v
"""





rs = np.linspace(0.5, 3.5, 50)

options_dict = {
    "basis": "6-311++G**",
    "scf_type": "pk",
    "e_convergence": 1e-10,
    "d_convergence": 1e-10,
    "frozen_docc" : [2, 0,0,0],
    "active" : [8,0,4,4],
    "num_roots" : 8, 
    "ci_maxiter" : 50, 
    'TDM' : True,
    "OPDM" : True,
    'dipmom' : True,
}
#    'num_roots' : 6,
#    'frozen_docc' : [28],
#    'active' : [12],
#    'TDM' :  True,
#    'OPDM': True,
#    'dipmom' : True
#}

mol = psi4.geometry(mol_str)
psi4.set_options(options_dict)
scf_e, wfn = psi4.energy('SCF', return_wfn=True)
fci_energy, wfn = psi4.energy('fci',ref_wfn=wfn, return_wfn=True)

# %% [markdown]
# # Note from quick calculation of CASCI(6,10)/6-311++G** Energy using Psi4 and Nam's Code:
# Root 4 from Psi4 (singles only) has the same energy as Root 30 at r = 0.6
# Psi4 Root 4:   -99.024284122838
# Nam's Root 30: -99.024284122837
#
# Properties computed using the CI ROOT 0 -> ROOT 1 density matrix
#
#
# Transition Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.7271143            0.0000000           -0.7271143
#  Magnitude           :                                                    0.7271143
#
#  ------------------------------------------------------------------------------------
#
# Properties computed using the CI ROOT 0 -> ROOT 2 density matrix
#
#
# Transition Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.0000000            0.0000000           -0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# Properties computed using the CI ROOT 0 -> ROOT 3 density matrix
#
#
# Transition Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.0583194            0.0000000           -0.0583194
#  Magnitude           :                                                    0.0583194
#
#  ------------------------------------------------------------------------------------
#
# Properties computed using the CI ROOT 0 -> ROOT 4 density matrix
#
#
# Transition Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -0.6029843            0.0000000           -0.6029843
#  Magnitude           :                                                    0.6029843
#
#  ------------------------------------------------------------------------------------

# %%
scf_e = []
eg = []
e1 = []
e2 = []
e3 = []
e4 = []
e5 = []
e6 = []
e7 = []
#e8 = []
for r_val in rs:
    mol_str = mol_tmpl.replace("**R**", str(r_val))
    print(mol_str)
    mol = psi4.geometry(mol_str)
    scfe, wfn = psi4.energy('SCF', return_wfn=True, molecule=mol)
    scf_e.append(scfe)
    ci_e, wfn = psi4.energy('fci',ref_wfn=wfn, return_wfn=True)
    eg.append(wfn.variable("CI ROOT 0 TOTAL ENERGY"))
    e1.append(wfn.variable("CI ROOT 1 TOTAL ENERGY"))
    e2.append(wfn.variable("CI ROOT 2 TOTAL ENERGY"))
    e3.append(wfn.variable("CI ROOT 3 TOTAL ENERGY"))
    e4.append(wfn.variable("CI ROOT 4 TOTAL ENERGY"))
    e5.append(wfn.variable("CI ROOT 5 TOTAL ENERGY"))
    e6.append(wfn.variable("CI ROOT 6 TOTAL ENERGY"))
    e7.append(wfn.variable("CI ROOT 7 TOTAL ENERGY"))
    #e8.append(wfn.variable("CI ROOT 6 TOTAL ENERGY"))
# Out:
# H
# F 1 0.5
# symmetry c2v
#
#
# H
# F 1 0.5612244897959183
# symmetry c2v
#
#
# H
# F 1 0.6224489795918368
# symmetry c2v
#
#
# H
# F 1 0.6836734693877551
# symmetry c2v
#
#
# H
# F 1 0.7448979591836735
# symmetry c2v
#
#
# H
# F 1 0.8061224489795918
# symmetry c2v
#
#
# H
# F 1 0.8673469387755102
# symmetry c2v
#
#
# H
# F 1 0.9285714285714286
# symmetry c2v
#
#
# H
# F 1 0.9897959183673469
# symmetry c2v
#
#
# H
# F 1 1.0510204081632653
# symmetry c2v
#
#
# H
# F 1 1.1122448979591837
# symmetry c2v
#
#
# H
# F 1 1.1734693877551021
# symmetry c2v
#
#
# H
# F 1 1.2346938775510203
# symmetry c2v
#
#
# H
# F 1 1.2959183673469388
# symmetry c2v
#
#
# H
# F 1 1.3571428571428572
# symmetry c2v
#
#
# H
# F 1 1.4183673469387754
# symmetry c2v
#
#
# H
# F 1 1.4795918367346939
# symmetry c2v
#
#
# H
# F 1 1.5408163265306123
# symmetry c2v
#
#
# H
# F 1 1.6020408163265305
# symmetry c2v
#
#
# H
# F 1 1.663265306122449
# symmetry c2v
#
#
# H
# F 1 1.7244897959183674
# symmetry c2v
#
#
# H
# F 1 1.7857142857142856
# symmetry c2v
#
#
# H
# F 1 1.846938775510204
# symmetry c2v
#
#
# H
# F 1 1.9081632653061225
# symmetry c2v
#
#
# H
# F 1 1.9693877551020407
# symmetry c2v
#
#
# H
# F 1 2.0306122448979593
# symmetry c2v
#
#
# H
# F 1 2.0918367346938775
# symmetry c2v
#
#
# H
# F 1 2.1530612244897958
# symmetry c2v
#
#
# H
# F 1 2.2142857142857144
# symmetry c2v
#
#
# H
# F 1 2.2755102040816326
# symmetry c2v
#
#
# H
# F 1 2.336734693877551
# symmetry c2v
#
#
# H
# F 1 2.3979591836734695
# symmetry c2v
#
#
# H
# F 1 2.4591836734693877
# symmetry c2v
#
#
# H
# F 1 2.520408163265306
# symmetry c2v
#
#
# H
# F 1 2.5816326530612246
# symmetry c2v
#
#
# H
# F 1 2.642857142857143
# symmetry c2v
#
#
# H
# F 1 2.704081632653061
# symmetry c2v
#
#
# H
# F 1 2.7653061224489797
# symmetry c2v
#
#
# H
# F 1 2.826530612244898
# symmetry c2v
#
#
# H
# F 1 2.887755102040816
# symmetry c2v
#
#
# H
# F 1 2.9489795918367347
# symmetry c2v
#
#
# H
# F 1 3.010204081632653
# symmetry c2v
#
#
# H
# F 1 3.071428571428571
# symmetry c2v
#
#
# H
# F 1 3.13265306122449
# symmetry c2v
#
#
# H
# F 1 3.193877551020408
# symmetry c2v
#
#
# H
# F 1 3.2551020408163263
# symmetry c2v
#
#
# H
# F 1 3.316326530612245
# symmetry c2v
#
#
# H
# F 1 3.377551020408163
# symmetry c2v
#
#
# H
# F 1 3.4387755102040813
# symmetry c2v
#
#
# H
# F 1 3.5
# symmetry c2v

# %%
from matplotlib import pyplot as plt
qed_fci_pes = np.load("hf_pes_35_states_only_singlets.npy")
#plt.plot(rs, eg, label="Psi4 E0") # X ^1\Sigma^+ minima 0.917 Ang.
#plt.plot(rs, e1, label="Psi4 E1") # B ^1\Sigma^+ bound but barely - minima ~2.151 Ang.
#plt.plot(rs, e2, label="Psi4 E2") # 1 ^1\Delta bound dipole forbidden - minima ~1.006 Ang
#plt.plot(rs, e3, label="Psi4 E3")
plt.plot(rs, e4, 'ro', label="Psi4 E4") # bound dipole allowed - minima ~1.17 Ang
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,1], 'yo', label="qed-fci E0")
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,2], 'ro', label="qed-fci E1")
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,3], 'bo', label="qed-fci E2")
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,4], 'go', label="qed-fci E3") # B ^1 \Sigma
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,5], 'y*', label="qed-fci E4")
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,6], 'r*', label="qed-fci E5")
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,7], 'b*', label="qed-fci E6") # 1 ^1\Delta 
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,8], 'g*', label="qed-fci E7")
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,9], 'y+', label="qed-fci E8")
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,10], 'r+', label="qed-fci E9")
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,11], 'b+', label="qed-fci E10")
plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,12], 'g+', label="qed-fci E11")
plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,13], 'y^', label="qed-fci E12") # same as psi4 E4
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,14], 'r^', label="qed-fci E13")
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,15], 'b^', label="qed-fci E14")
#plt.plot(qed_fci_pes[:,0], qed_fci_pes[:,16], 'g^', label="qed-fci E15")

#plt.xlim(0.8,1.5)
#plt.ylim(-99.45,-99.2)
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
#plt.plot(rs, scf_e, label="rhf")
plt.plot(rs, eg, label="E0")
plt.plot(rs, e1, label="E1")
plt.plot(rs, e2, label="E2")
plt.plot(rs, e3, label="E3")
plt.plot(rs, e4, label="E4")
plt.plot(rs, e5, label="E5")
plt.plot(rs, e6, label="E6")
plt.plot(rs, e7, label="E7")
plt.plot(rs, e8, label="E8")
#plt.plot(rs, e2)
plt.xlim(0.5,2.25)
#plt.ylim(-199.92, -199.7)
plt.legend()

#pes = np.array([[rs], [eg], [e1]])
#np.save("mghp_pes_casci_8_12_ccPVTZ.npy", pes)

# %%
pes_read = np.load("mghp_pes_casci_8_12_ccPVTZ.npy")
np.shape(pes_read)

plt.plot(rs, cceg, label="ccsd(t)")
plt.plot(rs, eg, label="Eg (6,16)")
plt.plot(rs, e1, label='E1 (6,16)')
plt.plot(rs, e3, label='E2 (6,16)')
#plt.plot(pes_read[0,0,:], pes_read[1,0,:], label='E1 (8, 12)')
#plt.plot(pes_read[0,0,:], pes_read[2,0,:], label='E2 (8, 12)')
#plt.plot(pes_read[0,0,:], pes_read[3,0,:], label='E3 (8, 12)')
plt.legend()
#plt.plot(rs, pes_read[1,0,:]-np.min(pes_read[1,0,:]))
#plt.plot(rs, pes_read[2,0,:])

#print(pes_read[1,0,:]-np.min(pes_read[1,0,:]))

# %%
ci_e, wfn = psi4.energy('fci',ref_wfn=wfn, return_wfn=True)
ener = psi4.get_variable('CI ROOT 0 -> ROOT 2 EXCITATION ENERGY')
print(fci_energy)
print(ener)

# %%
#transition density matrix
opdm_0 = wfn.get_opdm(1,4,"SUM", True)
dm = opdm_0.to_array()
print(dm)


#two electron integral
mints = psi4.core.MintsHelper(wfn.basisset())
I = mints.ao_eri()
D = I.to_array()
print(I.np)

#get transition dipole moment
props = ['DIPOLE', 'TRANSITION_DIPOLE']
psi4.properties('detci',properties=props)
M = ['X','Y','Z']
for i in range(6):
        for j in M:
                dipole=psi4.get_variable('CI ROOT %d -> ROOT %d DIPOLE %s'%(i,i+1,j))
                print('CI ROOT %d -> ROOT %d DIPOLE %s = %s'%(i,i+1,j,dipole))

# %% [markdown]
# Should look at 0->2 transition polarized along Y or the 0->5 transition polarized along Y
# 0->2: omega =
#
# At the CASCI(10,10)/cc-pVDZ level:
#    @CI 16:     0   -383.432630675633   2.3093E-14   1.5364E-06 c
#    @CI 16:     1   -383.229174086435   -7.1054E-15   2.1810E-06 c
#    @CI 16:     2   -383.214958443052   3.5527E-15   2.5621E-06 c
#    @CI 16:     3   -383.160173307314   -1.4211E-14   2.8093E-06 c
#    @CI 16:     4   -383.150441547330   -9.3614E-11   3.6503E-06 c
#    @CI 16:     5   -383.136370898717   2.8422E-14   2.1271E-06 c
#
#
# Properties computed using the CI ROOT 0 -> ROOT 1 density matrix
#
#
# Transition Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0109742            0.0000000           -0.0109742
#  Dipole Y            :          0.0000004            0.0000000            0.0000004
#  Dipole Z            :          0.0000006            0.0000000            0.0000006
#  Magnitude           :                                                    0.0109742
#
#  ------------------------------------------------------------------------------------
#
# Properties computed using the CI ROOT 0 -> ROOT 2 density matrix
#
#
# Transition Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000053            0.0000000            0.0000053
#  Dipole Y            :         -0.8601870            0.0000000           -0.8601870
#  Dipole Z            :         -0.0000003            0.0000000           -0.0000003
#  Magnitude           :                                                    0.8601870
#
#  ------------------------------------------------------------------------------------
#
# Properties computed using the CI ROOT 0 -> ROOT 3 density matrix
#
#
# Transition Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000005            0.0000000           -0.0000005
#  Dipole Y            :          0.0000002            0.0000000            0.0000002
#  Dipole Z            :          0.0000026            0.0000000            0.0000026
#  Magnitude           :                                                    0.0000026
#
#  ------------------------------------------------------------------------------------
#
# Properties computed using the CI ROOT 0 -> ROOT 4 density matrix
#
#
# Transition Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000016            0.0000000            0.0000016
#  Dipole Y            :          0.0000007            0.0000000            0.0000007
#  Dipole Z            :          0.0000006            0.0000000            0.0000006
#  Magnitude           :                                                    0.0000018
#
#  ------------------------------------------------------------------------------------
#
# Properties computed using the CI ROOT 0 -> ROOT 5 density matrix
#
#
# Transition Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000277            0.0000000           -0.0000277
#  Dipole Y            :          1.3532848            0.0000000            1.3532848
#  Dipole Z            :         -0.0000043            0.0000000           -0.0000043
#  Magnitude           :                                                    1.3532848
#
#  ------------------------------------------------------------------------------------

# %%
E = np.array([-383.432630675633, -383.229174086435, -383.214958443052, -383.160173307314, -383.150441547330, -383.136370898717])
omega_02 = E[2]-E[0]
omega_05 = E[5]-E[0]

print(omega_02)
print(omega_05)
