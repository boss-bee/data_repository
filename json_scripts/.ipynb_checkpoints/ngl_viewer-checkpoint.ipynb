# %%
import psi4
import numpy as np
from scipy.interpolate import InterpolatedUnivariateSpline
from numpy import linalg as LA
from psi4.driver.procrouting.response.scf_response import tdscf_excitations
import nglview

# %%
trans_s0 = psi4.geometry(""" 
 N -0.0000002584 0.4761975572 0.3945359199
 C 0.0000016133 0.1781634530 1.7872213143
 C -0.0000431852 1.2736724775 2.6359314022
 C -0.0000459828 1.0857647860 4.0105215159
 C -0.0000031946 -0.1994280957 4.5308021010
 C 0.0000444789 -1.2966614591 3.6757901950
 C 0.0000461540 -1.1131758542 2.3040861473
 H -0.0000780341 2.2563270882 2.2081506323
 H -0.0000848108 1.9339678566 4.6668892042
 H -0.0000049920 -0.3487777136 5.5933147807
 H 0.0000807982 -2.2904250056 4.0798421488
 H 0.0000847961 -1.9490322236 1.6355311542
 N -0.0000000374 -0.4656960273 -0.3944957528
 C 0.0000019782 -0.1760860514 -1.7813608900
 C -0.0000420565 -1.2837563061 -2.6299801717
 C -0.0000464841 -1.0967054273 -4.0160958567
 C -0.0000044138 0.1944791495 -4.5374022346
 C 0.0000443856 1.3008046888 -3.6702647186
 C 0.0000467476 1.1213388907 -2.3088032039
 H -0.0000755853 -2.2647344005 -2.1983986760
 H -0.0000806686 -1.9453266485 -4.6721799098
 H -0.0000042003 0.3481135168 -5.5992106109
 H 0.0000820252 2.2933219614 -4.0778541290
 H 0.0000842983 1.9587403887 -1.6419527136                                         
""")

ts_s0 = psi4.geometry("""
 N 0.4199987058 -1.5839917730 0.5897548848
 C 0.1017403426 -0.6478466899 1.5260494207
 C 0.9503574432 -0.6048680386 2.6733712977
 C 0.7212461800 0.2914194953 3.6795658481
 C -0.3634485792 1.1770432753 3.6052956579
 C -1.2171201186 1.1384580123 2.5064868945 
  C -1.0047729312 0.2481842218 1.4779743005
 H 1.7678020725 -1.2970023179 2.7112599635
 H 1.3707393301 0.3168910208 4.5328899404
 H -0.5402005722 1.8762845548 4.3989665593
 H -2.0557466774 1.8061217283 2.4618150926
 H -1.6841349294 0.2147272913 0.6516788032
 N -0.4199981527 -1.5839918836 -0.5897549907
 C -0.1017400900 -0.6478466405 -1.5260494435
 C -0.9503569040 -0.6048685751 -2.6733715014
 C -0.7212460117 0.2914190803 -3.6795660799
 C 0.3634481488 1.1770435255 -3.6052955998
 C 1.2171194141 1.1384588150 -2.5064866292
 C 1.0047725429 0.2481848826 -1.4779740590
 H -1.7678010769 -1.2970033855 -2.7112603278
 H -1.3707389675 0.3168901460 -4.5328903286
 H 0.5401999253 1.8762849106 -4.3989664580
 H 2.0557455386 1.8061230604 -2.4618146266
 H 1.6841343811 0.2147283906 -0.6516784166
""")

LiH = psi4.geometry("""
Li 
H  1 1.2
""")

H2O = psi4.geometry("""
O
H  1 1.0
H  1 1.0  2 104.5
""")

BH3 = psi4.geometry("""
B      0.000000000000   0.000000000000  -0.000000014895
H      -0.000000000000   0.000000000000   1.193230299466
H      1.033367824431   0.000000000000  -0.596615068378
H      -1.033367824431  -0.000000000000  -0.596615068378
""")

# %%
#mol = psi4.geometry('pubchem:napthalene')
#print(mol)
view = nglview.show_psi4(BH3)
view
# Out:
# NGLWidget()

# %%
psi4.set_options({
    'basis':'6-31G'
})

psi4.set_options({
    'save_jk': True,
    })  

#mol = psi4.geometry(ts_s0)
scf_e, wfn = psi4.energy('SCF', return_wfn=True, molecule=mol)
#psi4.set_options({'restricted_docc': [45],'active': [6],'num_roots': 4})
#fci_energy = psi4.energy('fci',ref_wfn=wfn, molecule=ts_s0)
# Out:
# Scratch directory: /tmp/
#
# *** tstart() called on CHEM353Q05NALT
# *** at Tue Aug  1 20:14:21 2023
#
#    => Loading Basis Set <=
#
#     Name: 6-31G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-10  entry C          line    87 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-31g.gbs
#     atoms 11-18 entry H          line    26 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-31g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
# ...

# %%
view = nglview.show_psi4(ts_s0)
view

# %%
psi4.set_options({
    'basis':'6-31G'
})

psi4.set_options({
    'save_jk': True,
    })  


#Calculate energy and wavefunction of ground state
#e, wfn = psi4.energy("CAM-b3lyp/6-31G", return_wfn=True, molecule=m_MTTM)
#e, wfn = psi4.energy("CAM-b3lyp/6-31G", return_wfn=True, molecule=ts_s0)


#res = tdscf_excitations(wfn, states=4, triplets = "NONE")

#mu = [r["ELECTRIC DIPOLE TRANSITION MOMENT (LEN)"] for r in res]

# %%
mol = psi4.geometry(ts_s0)
scf_e, wfn = psi4.energy('SCF', return_wfn=True)
psi4.set_options({'restricted_docc': [45],'active': [6],'num_roots': 4})
fci_energy = psi4.energy('fci',ref_wfn=wfn)

# %%
#psi4.set_options({
#    'opt_type': transition-state,
#    'full_hess_every' : 0
#    })  

#optimize('CAM-b3lyp/6-31G')
psi4.driver.optimize('CAM-b3lyp/6-31G', engine='optking', optimizer_keywords = {"opt_type" : "ts"})
# Out:
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on CHEM353Q05NALT
# *** at Wed Jul  5 19:13:23 2023
#
#    => Loading Basis Set <=
#
#     Name: 6-31G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 13       entry N          line   102 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-31g.gbs
#     atoms 2-7, 14-19  entry C          line    87 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-31g.gbs
#     atoms 8-12, 20-24 entry H          line    26 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/6-31g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,    500 MiB Core
# ...

# %%
mu_debye = np.sqrt((mu[0][0] ** 2) + (mu[0][1] ** 2) + (mu[0][2] ** 2)) / 0.393456

print(f' TDM_vec = {mu} au')
print(f'TDM_mag = {mu_debye} Debye')
