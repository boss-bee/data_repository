# %%
import numpy as np
from matplotlib import pyplot as plt
import json
import psi4
from matplotlib import cm
from matplotlib import rcParams

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

# %%
# imac
h2o_dir = "/Users/jayfoley/Code/data_repository/Mapol/H2O_ions/qed_fci/"
cas_6_11_dir = "/Users/jayfoley/Code/data_repository/Mapol/H2O_ions/qed_cas/6_11/"
cas_6_9_dir = "/Users/jayfoley/Code/data_repository/Mapol/H2O_ions/qed_cas/6_9/"
cas_6_6_dir = "/Users/jayfoley/Code/data_repository/Mapol/H2O_ions/qed_cas/6_6/"
# charlotte macs
#h2o_dir = "/Users/jfoley19/Code/data_repository/Mapol/H2O_ions/qed_fci/"
#cas_6_11_dir = "/Users/jfoley19/Code/data_repository/Mapol/H2O_ions/qed_cas/6_11/"

cs_1_file = h2o_dir + "H2O+_qed-cas_6-31G_coherent_state_basis_1_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_1_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_1_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_2_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_2_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_3_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_3_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_4_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_4_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_5_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_5_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_6_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_6_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_7_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_7_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_8_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_8_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_9_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_9_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_10_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_10_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"

cs_6_11_1_file = cas_6_11_dir + "H2O+_qed-cas_6-31G_coherent_state_basis_1_6_11_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
cs_6_9_1_file = cas_6_9_dir + "H2O+_qed-cas_6-31G_coherent_state_basis_1_6_9_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
cs_6_6_1_file = cas_6_6_dir + "H2O+_qed-cas_6-31G_coherent_state_basis_1_6_6_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"

pn_6_11_1_file = cas_6_11_dir + "H2O+_qed-cas_6-31G_photon_number_basis_1_6_11_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_6_9_1_file = cas_6_9_dir + "H2O+_qed-cas_6-31G_photon_number_basis_1_6_9_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_6_6_1_file = cas_6_6_dir + "H2O+_qed-cas_6-31G_photon_number_basis_1_6_6_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"

pn_6_11_10_file = cas_6_11_dir + "H2O+_qed-cas_6-31G_photon_number_basis_10_6_11_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_6_9_10_file = cas_6_9_dir + "H2O+_qed-cas_6-31G_photon_number_basis_10_6_9_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_6_6_10_file = cas_6_6_dir + "H2O+_qed-cas_6-31G_photon_number_basis_10_6_6_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"


print(pn_1_file)
# Out:
# /Users/jayfoley/Code/data_repository/Mapol/H2O_ions/qed_fci/H2O+_qed-cas_6-31G_photon_number_basis_1_8_13_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json

# %%
pn_1_data = json.load(open(pn_1_file))
pn_2_data = json.load(open(pn_2_file))
pn_3_data = json.load(open(pn_3_file))
pn_4_data = json.load(open(pn_4_file))
pn_5_data = json.load(open(pn_5_file))
pn_6_data = json.load(open(pn_6_file))
pn_7_data = json.load(open(pn_7_file))
pn_8_data = json.load(open(pn_8_file))
pn_9_data = json.load(open(pn_9_file))
pn_10_data = json.load(open(pn_10_file))

cs_6_11_1_data = json.load(open(cs_6_11_1_file))
cs_6_9_1_data = json.load(open(cs_6_9_1_file))
cs_6_6_1_data = json.load(open(cs_6_6_1_file))


pn_6_11_1_data = json.load(open(pn_6_11_1_file))
pn_6_9_1_data = json.load(open(pn_6_9_1_file))
pn_6_6_1_data = json.load(open(pn_6_6_1_file))
pn_6_11_10_data = json.load(open(pn_6_11_10_file))
pn_6_9_10_data = json.load(open(pn_6_9_10_file))
pn_6_6_10_data = json.load(open(pn_6_6_10_file))



cs_1_data = json.load(open(cs_1_file))

pn_1_energy = np.array(pn_1_data["return_result"])
pn_2_energy = np.array(pn_2_data["return_result"])
pn_3_energy = np.array(pn_3_data["return_result"])
pn_4_energy = np.array(pn_4_data["return_result"])
pn_5_energy = np.array(pn_5_data["return_result"])
pn_6_energy = np.array(pn_6_data["return_result"])
pn_7_energy = np.array(pn_7_data["return_result"])
pn_8_energy = np.array(pn_8_data["return_result"])
pn_9_energy = np.array(pn_9_data["return_result"])
pn_10_energy = np.array(pn_10_data["return_result"])

cs_6_11_1_energy = np.array(cs_6_11_1_data["return_result"])
cs_6_9_1_energy = np.array(cs_6_9_1_data["return_result"])
cs_6_6_1_energy = np.array(cs_6_6_1_data["return_result"])
cs_1_energy = np.array(cs_1_data["return_result"])


pn_6_11_1_energy = np.array(pn_6_11_1_data["return_result"])
pn_6_9_1_energy = np.array(pn_6_9_1_data["return_result"])
pn_6_6_1_energy = np.array(pn_6_6_1_data["return_result"])
pn_6_11_10_energy = np.array(pn_6_11_10_data["return_result"])
pn_6_9_10_energy = np.array(pn_6_9_10_data["return_result"])
pn_6_6_10_energy = np.array(pn_6_6_10_data["return_result"])

r_data = np.array(cs_1_data["molecule"]["bond_length"])

# %%
#plt.plot(r_data, cs_1_energy[:,0], 'black', label="CS-CQED-FCI-1")
plt.plot(r_data, (cs_6_11_1_energy[:,1]-cs_1_energy[:,1]), 'purple', marker="o", ms="6", label="CS-CQED-CASCI(6,11)-1")
plt.plot(r_data, (cs_6_9_1_energy[:,1]-cs_1_energy[:,1]), 'blue',  marker="o", ms="6",  label="CS-CQED-CASCI(6,9)-1")
plt.plot(r_data, (cs_6_6_1_energy[:,1]-cs_1_energy[:,1]), 'red',  marker="o", ms="6",  label="CS-CQED-CASCI(6,6)-1")
plt.yscale("log")
plt.ylim(10e-3, 5e-1)
plt.xticks([0,  4,  8,  12, 16, 20])
plt.xlim(0, 20)
plt.ylim(10e-3, 10e-1)
plt.ylabel("Error (Hartrees)")
plt.xlabel("Displacement from Origin (Angstroms))")
plt.legend()
plt.tight_layout()
plt.savefig("H2O2p_631G_CS-QEDCAS_1_displacement.png", dpi=150)
plt.show()
#'black', marker="s", ms="6", mfc='none', label="Converged Ground state")


#plt.plot(r_data, cs_1_energy[:,0], 'black', label="CS-CQED-FCI-1")
plt.plot(r_data, (pn_6_11_1_energy[:,1]-cs_1_energy[:,1]), 'purple', marker="o", ms="6", label="PN-CQED-CASCI(6,11)-1")
plt.plot(r_data, (pn_6_9_1_energy[:,1]-cs_1_energy[:,1]), 'blue',  marker="o", ms="6",  label="PN-CQED-CASCI(6,9)-1")
plt.plot(r_data, (pn_6_6_1_energy[:,1]-cs_1_energy[:,1]), 'red',  marker="o", ms="6",  label="PN-CQED-CASCI(6,6)-1")
plt.yscale("log")
plt.ylim(10e-3, 10e-1)
plt.xticks([0,  4,  8,  12, 16, 20])
plt.xlim(0, 20)
plt.ylabel("Error (Hartrees)")
plt.xlabel("Displacement from Origin (Angstroms))")
plt.legend()
plt.tight_layout()
plt.savefig("H2O2p_631G_PN-QEDCAS_1_displacement.png", dpi=150)
plt.show()
#'black', marker="s", ms="6", mfc='none', label="Converged Ground state")


plt.plot(r_data, (pn_6_11_10_energy[:,1]-cs_1_energy[:,1]), 'purple', marker="o", ms="6", label="PN-CQED-CASCI(6,11)-10")
plt.plot(r_data, (pn_6_9_10_energy[:,1]-cs_1_energy[:,1]), 'blue',  marker="o", ms="6",  label="PN-CQED-CASCI(6,9)-10")
plt.plot(r_data, (pn_6_6_10_energy[:,1]-cs_1_energy[:,1]), 'red',  marker="o", ms="6",  label="PN-CQED-CASCI(6,6)-10")
plt.yscale("log")
plt.ylim(10e-3, 10e-1)
plt.xticks([0,  4,  8,  12, 16, 20])
plt.xlim(0, 20)
plt.ylabel("Error (Hartrees)")
plt.xlabel("Displacement from Origin (Angstroms))")
plt.legend()
plt.tight_layout()
plt.savefig("H2O2p_631G_PN-QEDCAS_10_displacement.png", dpi=150)
plt.show()
#'black', marker="s", ms="6", mfc='none', label="Converged Ground state")

# %%
#plt.plot(r_data, cs_1_energy[:,1]-cs_1_energy[:,1], 'black', label="Coherent State, Np = 1")
plt.plot(r_data, pn_1_energy[:,1]-cs_1_energy[:,1], 'red', marker="o", ms="6", label="1")
plt.plot(r_data, pn_2_energy[:,1]-cs_1_energy[:,1], 'orange',  marker="o", ms="6",  label="2")
#plt.plot(r_data, pn_3_energy[:,1]-cs_1_energy[:,1], 'purple', linestyle="dashed", label="Np = 3")
plt.plot(r_data, pn_4_energy[:,1]-cs_1_energy[:,1], 'green',  marker="o", ms="6",  label="4")
#plt.plot(r_data, pn_5_energy[:,1]-cs_1_energy[:,1], 'blue', linestyle="dashed", label="Np = 5")
plt.plot(r_data, pn_6_energy[:,1]-cs_1_energy[:,1], 'blue',  marker="o", ms="6",  label="6")
#plt.plot(r_data, pn_7_energy[:,1]-cs_1_energy[:,1], 'green', linestyle="dashed", label="Np = 7")
plt.plot(r_data, pn_8_energy[:,1]-cs_1_energy[:,1], 'purple',  marker="o", ms="6", label="8")
#plt.plot(r_data, pn_10_energy[:,1]-cs_1_energy[:,1], 'black',  marker="s", ms="6", mfc='none', label="Np = 10")
plt.yscale("log")
plt.ylim(10e-9, 5e-0)
plt.xticks([0,  4,  8,  12, 16, 20])
plt.xlim(0, 20)
plt.ylabel("Error (Hartrees)")
plt.xlabel("Displacement from Origin (Angstroms))")
plt.legend()
plt.tight_layout()
plt.savefig("H2O2p_631G_FCI_displacement.png", dpi=150)
plt.show()
#'black', marker="s", ms="6", mfc='none', label="Converged Ground state")

# %% [markdown]
# Running additional calculations at the qed-fci level in the photon number basis with $\lambda_z = 0.01$ a.u. and $\omega=10$ eV.  In particular, varying photon number in increments of 1 and varying displacement in increments of 1 angstrom.

# %%
h2o_dir = "/Users/jfoley19/Code/data_repository/Mapol/H2O_ions/"


cs_6_11_1_file = h2o_dir + "H2O+_qed-cas_6-31G_coherent_state_basis_1_6_11_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
cs_6_11_2_file = h2o_dir + "H2O+_qed-cas_6-31G_coherent_state_basis_2_6_11_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
cs_6_11_5_file = h2o_dir + "H2O+_qed-cas_6-31G_coherent_state_basis_5_6_11_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"


cs_6_11_1_data = json.load(open(cs_6_11_1_file))
cs_6_11_2_data = json.load(open(cs_6_11_1_file))
cs_6_11_5_data = json.load(open(cs_6_11_1_file))

cs_6_11_1_energy = np.array(cs_6_11_1_data["return_result"])
cs_6_11_2_energy = np.array(cs_6_11_2_data["return_result"])
cs_6_11_5_energy = np.array(cs_6_11_5_data["return_result"])

pn_6_11_1_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_1_6_11_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_6_11_2_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_2_6_11_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"
pn_6_11_5_file = h2o_dir + "H2O+_qed-cas_6-31G_photon_number_basis_5_6_11_lambda_0.0_0.0_0.01_omega_0.36749303600696764.json"


pn_6_11_1_data = json.load(open(pn_6_11_1_file))
pn_6_11_2_data = json.load(open(pn_6_11_1_file))
pn_6_11_5_data = json.load(open(pn_6_11_1_file))

pn_6_11_1_energy = np.array(pn_6_11_1_data["return_result"])
pn_6_11_2_energy = np.array(pn_6_11_2_data["return_result"])
pn_6_11_5_energy = np.array(pn_6_11_5_data["return_result"])

print(cs_6_11_1_energy[1,0]-cs_1_energy[1,0])
print(pn_6_11_5_energy[1,1]-cs_1_energy[1,0])
# Out:
# 0.011808209435855588
# 0.1772513566274796

# %% [markdown]
# Going to look at the error of H2O$^{2+}$ vs $\lambda_z$ for qed-cas(n,m)/6-31G in the coherent state and photon number state basis where (n,m) = (6,11) and (6,9) and the error is defined relative to qed-fci(n,m)/6-31G.  Np = 1 will be used for all calculations.

# %%
cs_6_11 = h2o_dir + "H2O+_qed-fci_6-31g_coherent_state_basis_1_6_11_omega_0.36749303600696764.json"
cs_6_9 = h2o_dir + "H2O+_qed-fci_6-31g_coherent_state_basis_1_6_9_omega_0.36749303600696764.json"
cs_8_13 = h2o_dir + "H2O+_qed-fci_6-31g_coherent_state_basis_1_8_13_omega_0.36749303600696764.json"
pn_6_11 = h2o_dir + "H2O+_qed-fci_6-31g_photon_number_basis_1_6_11_omega_0.36749303600696764.json"
pn_6_9 = h2o_dir + "H2O+_qed-fci_6-31g_photon_number_basis_1_6_9_omega_0.36749303600696764.json"
#cs_fci = h2o_dir + "H2O+_qed-fci_sto-3g_coherent_state_basis_5_8_13_omega_0.36749303600696764.json"

cs_6_11_data = json.load(open(cs_6_11))
cs_6_9_data = json.load(open(cs_6_9))
cs_8_13_data = json.load(open(cs_8_13))

pn_6_11_data = json.load(open(pn_6_11))
pn_6_9_data = json.load(open(pn_6_9))
cs_fci_data = json.load(open(cs_fci))

cs_6_11_energy = np.array(cs_6_11_data["return_result"])
cs_6_9_energy = np.array(cs_6_9_data["return_result"])
cs_8_13_energy = np.array(cs_8_13_data["return_result"])
cs_fci_energy = np.array(cs_fci_data["return_result"])

pn_6_11_energy = np.array(pn_6_11_data["return_result"])
pn_6_9_energy = np.array(pn_6_9_data["return_result"])

lamz = np.array(pn_6_9_data["model"]["lambda"])[:,2]
# Out:
# [0.    0.005 0.01  0.015 0.02  0.025 0.03  0.035 0.04  0.045 0.05 ]

# %%
#plt.plot(lamz, cs_8_13_energy[:,1], label='cs fci')
plt.plot(lamz, cs_6_11_energy[:,2], label="cs 6,11")
#plt.plot(lamz, cs_6_9_energy[:,1], label="cs 6,9")
plt.plot(lamz, pn_6_11_energy[:,2], linestyle="dashed", label="pn 6,11")
#plt.plot(lamz, pn_6_9_energy[:,1], label="pn 6,9")
plt.legend()
