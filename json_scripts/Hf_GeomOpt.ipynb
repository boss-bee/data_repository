# %%
import numpy as np
from matplotlib import pyplot as plt
import psi4

# %%
mol_str = """
Li
H 1 1.67295
symmetry c1
"""

options_dict = {
    "basis": "6-31G",
    "scf_type": "pk",
    "e_convergence": 1e-10,
    "d_convergence": 1e-10,
}

mol = psi4.geometry(mol_str)
psi4.set_options(options_dict)
scf_e, wfn = psi4.energy('SCF', return_wfn=True)
fci_energy, wfn = psi4.frequency('fci',ref_wfn=wfn, return_wfn=True)
# Out:
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEM353Q05NALT
# *** at Wed May  1 13:40:24 2024
#
#    => Loading Basis Set <=
#
#     Name: 6-31G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry LI         line    42 file /opt/homebrew/Caskroom/miniforge/base/envs/p4env/share/psi4/basis/6-31g.gbs
#     atoms 2 entry H          line    26 file /opt/homebrew/Caskroom/miniforge/base/envs/p4env/share/psi4/basis/6-31g.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
# ...
