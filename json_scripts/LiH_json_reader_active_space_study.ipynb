# %%
import json
import numpy as np

# %%
# json file name
subdirname = "/Users/jfoley19/Code/data_repository/Mapol/LiH/qed_fci/"

ref_file = "LiH_qed-fci_6-311g_coherent_state_basis_10_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"


reff1 = open(subdirname + ref_file)
rdata = json.load(reff1)
ref_data = np.array(rdata["return_result"])
r_data = np.linspace(1.4, 2.2, 50)

# %%
# directory with qed-casci data
casdir = "/Users/jfoley19/Code/data_repository/Mapol/LiH/qed_cas/"

# file names with different numbers of virtual orbitals
fn_2v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_2_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_3v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_3_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_4v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_4_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_5v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_5_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_6v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_6_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_7v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_7_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_8v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_8_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_9v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_9_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_10v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_10_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_11v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_11_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_12v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_12_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_13v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_13_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_14v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_14_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_15v = casdir + "LiH_qed-fci_6-311g_coherent_state_basis_10_4_15_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
fn_16v = casdir + "LiH_qed-cas_6-311g_coherent_state_basis_10_4_16_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"

pn_2v = casdir + "LiH_qed-cas_6-311g_photon_number_basis_10_4_2_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
pn_3v = casdir + "LiH_qed-cas_6-311g_photon_number_basis_10_4_3_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
pn_4v = casdir + "LiH_qed-cas_6-311g_photon_number_basis_10_4_4_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
pn_5v = casdir + "LiH_qed-cas_6-311g_photon_number_basis_10_4_5_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
pn_6v = casdir + "LiH_qed-cas_6-311g_photon_number_basis_10_4_6_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
pn_7v = casdir + "LiH_qed-cas_6-311g_photon_number_basis_10_4_7_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
pn_8v = casdir + "LiH_qed-cas_6-311g_photon_number_basis_10_4_8_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
pn_9v = casdir + "LiH_qed-cas_6-311g_photon_number_basis_10_4_9_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"
pn_10v = casdir + "LiH_qed-cas_6-311g_photon_number_basis_10_4_10_lambda_0.0_0.0_0.05__singlet_omega_0.12086.json"

#df2 = json.load(open(fn_2v))
df3 = json.load(open(fn_3v))
df4 = json.load(open(fn_4v))
df5 = json.load(open(fn_5v))
df6 = json.load(open(fn_6v))
df7 = json.load(open(fn_7v))
df8 = json.load(open(fn_8v))
df9 = json.load(open(fn_9v))
df10 = json.load(open(fn_10v))
df11 = json.load(open(fn_11v))
df12 = json.load(open(fn_12v))
df13 = json.load(open(fn_13v))
df14 = json.load(open(fn_14v))
df15 = json.load(open(fn_15v))
df16 = json.load(open(fn_16v))

#pf2 = json.load(open(pn_2v))
pf3 = json.load(open(pn_3v))
pf4 = json.load(open(pn_4v))
pf5 = json.load(open(pn_5v))
pf6 = json.load(open(pn_6v))
pf7 = json.load(open(pn_7v))
pf8 = json.load(open(pn_8v))
pf9 = json.load(open(pn_9v))
pf10 = json.load(open(pn_10v))

#pf11 = json.load(open(fn_11v))
#pf12 = json.load(open(fn_12v))
#pf13 = json.load(open(fn_13v))
#pf14 = json.load(open(fn_14v))
#pf15 = json.load(open(fn_15v))
#pf16 = json.load(open(fn_16v))

#eig2 = np.array(df2["return_result"])
eig3 = np.array(df3["return_result"])
eig4 = np.array(df4["return_result"])
eig5 = np.array(df5["return_result"])
eig6 = np.array(df6["return_result"])
eig7 = np.array(df7["return_result"])
eig8 = np.array(df8["return_result"])
eig9 = np.array(df9["return_result"])
eig10 = np.array(df10["return_result"])
eig11 = np.array(df11["return_result"])
eig12 = np.array(df12["return_result"])
eig13 = np.array(df13["return_result"])
eig14 = np.array(df14["return_result"])
eig15 = np.array(df15["return_result"])
eig16 = np.array(df16["return_result"])


#peig2 = np.array(pf2["return_result"])
peig3 = np.array(pf3["return_result"])
peig4 = np.array(pf4["return_result"])
peig5 = np.array(pf5["return_result"])
peig6 = np.array(pf6["return_result"])
peig7 = np.array(pf7["return_result"])
peig8 = np.array(pf8["return_result"])
peig9 = np.array(pf9["return_result"])
peig10 = np.array(pf10["return_result"])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[35], line 91
#      88 peig9 = np.array(pf9["return_result"])
#      89 peig10 = np.array(pf10["return_result"])
# ---> 91 assert np.allclose(peig3[:,0], eig3[:,0])
#
# AssertionError:

# %%
def mae(array, reference):
    diff = np.abs(array - reference)
    mae = np.mean(diff)
    return mae

# %%
cs_mae = np.zeros(14)
np_mae = np.zeros(14)
numph = np.linspace(3, 16, 14, dtype=int)

# %%
cs_mae[0] = mae(eig3[:,0], ref_data[:,0])
cs_mae[1] = mae(eig4[:,0], ref_data[:,0])
cs_mae[2] = mae(eig5[:,0], ref_data[:,0])
cs_mae[3] = mae(eig6[:,0], ref_data[:,0])
cs_mae[4] = mae(eig7[:,0], ref_data[:,0])
cs_mae[5] = mae(eig8[:,0], ref_data[:,0])
cs_mae[6] = mae(eig9[:,0], ref_data[:,0])
cs_mae[7] = mae(eig10[:,0], ref_data[:,0])
#cs_mae[8] = mae(eig10[:,0], ref_data[:,0])
#cs_mae[9] = mae(eig11[:,0], ref_data[:,0])
#cs_mae[10] = mae(eig12[:,0], ref_data[:,0])
#cs_mae[11] = mae(eig13[:,0], ref_data[:,0])
#cs_mae[12] = mae(eig14[:,0], ref_data[:,0])
#cs_mae[13] = mae(eig15[:,0], ref_data[:,0])
#cs_mae[14] = mae(eig16[:,0], ref_data[:,0])

np_mae[0] = mae(peig3[:,0], ref_data[:,0])
np_mae[1] = mae(peig4[:,0], ref_data[:,0])
np_mae[2] = mae(peig5[:,0], ref_data[:,0])
np_mae[3] = mae(peig6[:,0], ref_data[:,0])
np_mae[4] = mae(peig7[:,0], ref_data[:,0])
np_mae[5] = mae(peig8[:,0], ref_data[:,0])
np_mae[6] = mae(peig9[:,0], ref_data[:,0])
np_mae[7] = mae(peig10[:,0], ref_data[:,0])
#np_mae[8] = mae(peig10[:,0], ref_data[:,0])
#np_mae[9] = mae(eig11[:,0], ref_data[:,0])
#np_mae[10] = mae(eig12[:,0], ref_data[:,0])
#np_mae[11] = mae(eig13[:,0], ref_data[:,0])
#np_mae[12] = mae(eig14[:,0], ref_data[:,0])
#np_mae[13] = mae(eig15[:,0], ref_data[:,0])
#np_mae[14] = mae(eig16[:,0], ref_data[:,0])

# %%
from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib import rcParams

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

plt.plot(numph[:8], np_mae[:8], "r-o", label="Photon Number Basis")
plt.plot(numph[:8], cs_mae[:8], "b-o", label="Coherent State Basis")
plt.yscale("log")
#plt.ylim(0.5e-10, 1e-3)
plt.xlabel("Number of photon states")
plt.ylabel("Mean Absolute Error (Hartrees)")
plt.legend()
plt.tight_layout()
#plt.savefig("LiH_error_vs_np.eps", dpi=150)
plt.show()

# %%
plt.plot(r_data, ref_data[:,0])
plt.plot(r_data, eig2[:,0])
plt.plot(r_data, eig15[:,0])
plt.plot(r_data, eig16[:,0], "b*")
