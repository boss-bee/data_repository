# %%
import numpy as np
from matplotlib import pyplot as plt
import psi4

# %%
mol_str = """
O
H 1 1.0
-1 1
symmetry c1
"""

options_dict = {
    "basis": "cc-pVDZ",
    "e_convergence": 1e-10,
    "d_convergence": 1e-10,
}

mol = psi4.geometry(mol_str)
psi4.set_options(options_dict)
scf_e, wfn = psi4.optimize('mp2', return_wfn=True)
#fci_energy, wfn = psi4.energy('fci',ref_wfn=wfn, return_wfn=True)
# Out:
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#     SCF Algorithm Type (re)set to DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYY31VALT
# *** at Tue Dec  5 12:25:28 2023
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry O          line   198 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/cc-pvdz.gbs
#     atoms 2 entry H          line    22 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
# ...

# %%
com_str = """
O            0.000000000000     0.000000000000    -0.058094486598    
H            0.000000000000     0.000000000000     0.922001660302   
-1 1
symmetry c1
"""

options_dict = {
    "basis": "cc-pVDZ",
    "e_convergence": 1e-10,
    "d_convergence": 1e-10,
}

mol = psi4.geometry(com_str)
psi4.set_options(options_dict)
scf_e, wfn = psi4.energy('mp2', return_wfn=True)
# Out:
# Scratch directory: /tmp/
#     SCF Algorithm Type (re)set to DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYY31VALT
# *** at Tue Dec  5 12:31:19 2023
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry O          line   198 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/cc-pvdz.gbs
#     atoms 2 entry H          line    22 file /Users/jfoley19/Code/psi4/objdir-Release/stage/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
# ...
